# %% [markdown]
# # **YouTube Data Haversting And Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Extracting data from youtube**
#
# ![1_vsSAd7JK3QbEPLaDMPpMcw.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Install google-api-python-client**

# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.84.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)

# %% [markdown]
# #**Import google-api-python-client, pandas**

# %%
from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# #**Create API object**

# %%
def API_connect():
    API_key = "AIzaSyCEPybqwz_6JrOgLG3S-9LFJohlbmXm4hM" #API key   "AIzaSyCtIglCyp5-nFeUXB1Hg1HMFMo5bh3LDQc"

    api_service_name = "youtube" #API service name
    api_version = "v3" #API version
    youtube = build(api_service_name, api_version, developerKey=API_key) #API object
    return youtube

# %%
youtube=API_connect()

# %% [markdown]
# #**Get channel details**

# %%
Channel_name = input("Enter channel name: ")
request = youtube.search().list(
        part="id,snippet",
        channelType="any",
        maxResults=1,
        q=Channel_name,
    )
response = request.execute()

response
# Out:
# Enter channel name: chennai super kings
# {'kind': 'youtube#searchListResponse',
#  'etag': 'AJXOu-v2dxGy6yHyiDTmraenq9Q',
#  'nextPageToken': 'CAEQAA',
#  'regionCode': 'TW',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'i7F4UW761mIrxi3MZptOS1k_Oak',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw'},
#    'snippet': {'publishedAt': '2009-04-17T13:00:30Z',
#     'channelId': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#     'title': 'Chennai Super Kings',
#     'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'Chennai Super Kings',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2009-04-17T13:00:30Z'}}]}

# %%
channel_id = response["items"][0]["id"]['channelId']
Channel_name = response["items"][0]["snippet"]["title"]


print('Channel_name', Channel_name)
print('Channel_id', channel_id)
# Out:
# Channel_name Chennai Super Kings
# Channel_id UC2J_VKrAzOEJuQvFFtj3KUw

# %%
 #API object

#Get channel id
#channel_id = input("Enter channel id: ")
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id)
response = request.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '3C6tljRf2f7NEGuiNQKmdsDVmns',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'UhySILpUQPBBPMKVl6y1ogvLBU0',
#    'id': 'UC2J_VKrAzOEJuQvFFtj3KUw',
#    'snippet': {'title': 'Chennai Super Kings',
#     'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove',
#     'customUrl': '@chennaiipl',
#     'publishedAt': '2009-04-17T13:00:30Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/Nt8wKzf7bK6j0aG6CDvymMoPnPbCEx0gnyMcOZDJuKYALlHUfVmEMhe7zaGDHwDjb7Fu9DrV8Q=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Chennai Super Kings',
#      'description': 'The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove'},
#     'country': 'IN'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU2J_VKrAzOEJuQvFFtj3KUw'}},
#    'statistics': {'viewCount': '619226573',
#     'subscriberCount': '3140000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '1092'}}]}

# %% [markdown]
# #**Take Channel id, channel name and channel description, channel subscriber count, channel view count, channel video count, channel published date, upload playlist**

# %%
channel_id = response["items"][0]["id"]
Channel_name = response["items"][0]["snippet"]["title"]
Channel_description = response["items"][0]["snippet"]["description"]
Channel_subscribers = response["items"][0]["statistics"]["subscriberCount"]
Channel_view_Count = response["items"][0]["statistics"]["viewCount"]
channel_Video_Count = response["items"][0]["statistics"]["videoCount"]
Channel_Published_Date = response["items"][0]["snippet"]["publishedAt"]
Playlist_id = response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]


print('Channel_name :', Channel_name)
print('Channel_id :', channel_id)
print('Channel_description :', Channel_description)
print('Channel_subscribers :', Channel_subscribers)
print('Channel_view_Count :', Channel_view_Count)
print('channel_Video_Count :', channel_Video_Count)
print('Channel_Published_Date :', Channel_Published_Date)
print('Playlist_id :', Playlist_id)
# Out:
# Channel_name : Chennai Super Kings
# Channel_id : UC2J_VKrAzOEJuQvFFtj3KUw
# Channel_description : The Official YouTube Channel of the Chennai Super Kings. #WhistlePodu #Yellove
# Channel_subscribers : 3140000
# Channel_view_Count : 619226573
# channel_Video_Count : 1092
# Channel_Published_Date : 2009-04-17T13:00:30Z
# Playlist_id : UU2J_VKrAzOEJuQvFFtj3KUw

# %%
ChannelDetails = pd.DataFrame({
    "Channel_id": channel_id,
    "Channel_name": Channel_name,
    "Channel_description": Channel_description,
    "Channel_subscribers": Channel_subscribers,
    "Channel_view_Count": Channel_view_Count,
    "channel_Video_Count": channel_Video_Count,
    "Channel_Published_Date": Channel_Published_Date,
    "Playlist_id": Playlist_id
    }, index=[0])
ChannelDetails
# Out:
#                  Channel_id         Channel_name  \
# 0  UC2J_VKrAzOEJuQvFFtj3KUw  Chennai Super Kings
#
#                                  Channel_description Channel_subscribers  \
# 0  The Official YouTube Channel of the Chennai Su...             3140000
#
#   Channel_view_Count channel_Video_Count Channel_Published_Date  \
# 0          619226573                1092   2009-04-17T13:00:30Z
#
#                 Playlist_id
# 0  UU2J_VKrAzOEJuQvFFtj3KUw

# %% [markdown]
# #**Get video id from playlist**

# %%
#Get video id from playlist id
playlist_id = Playlist_id
request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
response = request.execute()

Video_id = []
for item in response['items']:
    video_id = item['contentDetails']['videoId']
    print(video_id)
    Video_id.append(video_id)

print("Number of videos in playlist:", len(Video_id))
# Out:
# f1gnaV4sWYo
# 85adJ60bQqk
# zdZmopaH8vA
# r88fWNdYmPc
# o29L2ysDYeY
# DntAi1keBkg
# sWldDPznq60
# R6v4PyiDOMI
# 51BFx3J2Ru4
# xlripGf89Aw
# Q4wsTEV8_XM
# XZ0n5vOCj6U
# W4P5AyK7Ues
# RtD4q4LnLUw
# WxbZtVJLID4
# 9OPmzW31nzk
# MbzuFYeq4aU
# fGHl5k_PyNE
# g87iuCiFM0E
# 1QyC0VyxjUA
# JNs4p0pk8Ms
# dsMLIZKIEd8
# QJNsvEta0UI
# iVWyETew2KM
# 0b6rhoi1pAQ
# RF3gM9MUPwk
# FCJyVOtupZg
# -zEynAwpLVI
# _xYIJwAgJ_k
# as-5cUQfhBk
# ss4vpidhoHU
# mXm-VjKPd1g
# k-QBfI95DT8
# z4fIO1-qF5Q
# AD75Jds6EfI
# mh9Mqqdvs9c
# 6t0tazaQy5U
# r7X4ww16H68
# D9_FvFWvSAw
# 3CGVbrCOrsA
# vKaEjIPEGxc
# 3hFftuQdwSs
# 2Xh24NockS4
# uhOjJIS5HIQ
# wleEunjXJLk
# OOCfxuEmSCk
# cA-U338hrdI
# rFGr1pg5_Uc
# PLg5FgZjVyA
# 3aOXY3j8YNc
# Number of videos in playlist: 50

# %% [markdown]
# #**we need to get video id from playlist id for next page**

# %%
video_ids = []                                          #list of video id

request = youtube.playlistItems().list(
    part="snippet,contentDetails",
    playlistId=playlist_id,
    maxResults=50
)
response = request.execute()

for item in response['items']:                            #loop to get video id
    video_ids.append(item['contentDetails']['videoId'])

next_page_token = response.get('nextPageToken')           #get next page
while next_page_token is not None:                        #loop to get video id
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50,
        pageToken=next_page_token)
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId']) #append video id

    next_page_token = response.get('nextPageToken')        #get next page

print("Number of videos in playlist:", len(video_ids))    #print number of videos
# Out:
# Number of videos in playlist: 1092

# %% [markdown]
# # **Get video details**

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i + 50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'commentCount']
                             }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)

    return all_video_info

# %%
videos=get_video_details(youtube, video_ids)
videos
# Out:
# [{'video_id': 'f1gnaV4sWYo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'That sounds Mo like a perfect team 😎Pick yours here📎 bit.ly/42k8NkQ',
#   'description': '',
#   'publishedAt': '2023-07-21T09:10:58Z',
#   'viewCount': '15105',
#   'likeCount': '1885',
#   'commentCount': '22'},
#  {'video_id': '85adJ60bQqk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Thala's birthday gift 🎥💛#CelebratingThala #WhistlePodu 🦁",
#   'description': '',
#   'publishedAt': '2023-07-08T11:26:55Z',
#   'viewCount': '153634',
#   'likeCount': '28322',
#   'commentCount': '309'},
#  {'video_id': 'zdZmopaH8vA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The THALA Emotion - MS Dhoni Birthday Special | #CelebratingThala',
#   'description': "It's his day, our day! Join in as we celebrate the man who leads the pride! \n\n#CelebratingThala #WhistlePodu #Yellove",
#   'publishedAt': '2023-07-07T09:08:20Z',
#   'viewCount': '200780',
#   'likeCount': '21810',
#   'commentCount': '1160'},
#  {'video_id': 'r88fWNdYmPc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Test Cricket’s an art and Bens got those master Strokes! 💪🏻#TheAshes #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-07-04T11:17:36Z',
#   'viewCount': '41837',
#   'likeCount': '5772',
#   'commentCount': '28'},
#  {'video_id': 'o29L2ysDYeY',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Does your All time XI match with that of Conway's ?Pick here 🔗 https://bit.ly/3D1WtKk",
#   'description': '',
#   'publishedAt': '2023-07-03T10:46:32Z',
#   'viewCount': '42806',
#   'likeCount': '6491',
#   'commentCount': '78'},
#  {'video_id': 'DntAi1keBkg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Season that was - Rewind to Summer of 2023 #WhistlePodu',
#   'description': "The Season that was! Here's the super cut of the summer of 2023! \n\n#ReliveChampions23 #WhistlePodu",
#   'publishedAt': '2023-06-30T14:14:38Z',
#   'viewCount': '225054',
#   'likeCount': '13327',
#   'commentCount': '266'},
#  {'video_id': 'sWldDPznq60',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Moments that keep reeling forever in our hearts! 💛  Be a part of it 🔗 https://bit.ly/3NQ6mRI',
#   'description': '',
#   'publishedAt': '2023-06-29T14:11:59Z',
#   'viewCount': '148027',
#   'likeCount': '18404',
#   'commentCount': '116'},
#  {'video_id': 'R6v4PyiDOMI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Your Monday evening Blockbuster!💥🥳#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-06-26T12:55:50Z',
#   'viewCount': '72925',
#   'likeCount': '10605',
#   'commentCount': '64'},
#  {'video_id': '51BFx3J2Ru4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ashes Action Block Ft. Ben Stokes and Moeen Ali',
#   'description': 'We’re always up for a taste of test cricket! Here’s Ben and Mo on the format and #TheAshes Challenge \n\n#WhistlePodu #Yellove 💛🦁',
#   'publishedAt': '2023-06-16T10:09:12Z',
#   'viewCount': '29644',
#   'likeCount': '1736',
#   'commentCount': '69'},
#  {'video_id': 'xlripGf89Aw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Journey from Jharkhand to Chennai | Anbuden Diaries ft. Rajiv Kumar',
#   'description': 'The Journey from Jharkhand to becoming an integral part of the Super Kings coaching setup!\n\nAnbuden Diaries ft. Rajiv Kumar 📽️🔗\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-06-08T08:17:10Z',
#   'viewCount': '20709',
#   'likeCount': '1411',
#   'commentCount': '97'},
#  {'video_id': 'Q4wsTEV8_XM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ajinkya Rahane opens up on the India vs Australia Memories #INDvAUS | #WTCFinal',
#   'description': "Ajju's memories on the Aussie tussle 📹\nFull Video 🔗https://bit.ly/3Ca9t02\n\n#INDvAUS #WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-06-05T11:37:30Z',
#   'viewCount': '28856',
#   'likeCount': '2155',
#   'commentCount': '86'},
#  {'video_id': 'XZ0n5vOCj6U',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Going Ben Strokes on his BDAY! 💥#SuperBirthday #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-06-04T15:54:56Z',
#   'viewCount': '156056',
#   'likeCount': '19306',
#   'commentCount': '116'},
#  {'video_id': 'W4P5AyK7Ues',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Thala is an emotion \U0001f979#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-06-03T13:44:09Z',
#   'viewCount': '424298',
#   'likeCount': '63334',
#   'commentCount': '324'},
#  {'video_id': 'RtD4q4LnLUw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Celebrating the Super Kings Way | #CHAMPION5 #IPL2023',
#   'description': 'Peek into the Celebrations of the Super Kings inside the Dressing Room, Team Bus, Hotel and more..!\n\n#WhistlePodu #Yellove',
#   'publishedAt': '2023-06-02T06:40:40Z',
#   'viewCount': '1521020',
#   'likeCount': '72265',
#   'commentCount': '1518'},
#  {'video_id': 'WxbZtVJLID4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'CSK #SuperChampions celebrations - IPL 2023 Final | #CSKvGT',
#   'description': '5INALLY THE CELEBRATIONS! 🥳\n\n#CHAMPION5 #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-30T01:56:52Z',
#   'viewCount': '1258113',
#   'likeCount': '66323',
#   'commentCount': '2403'},
#  {'video_id': '9OPmzW31nzk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Action Unfiltered - The Last Grind before the Finale',
#   'description': 'As we get set for the grand title challenge, soak up in the raw action from Ahmedabad!',
#   'publishedAt': '2023-05-28T11:45:48Z',
#   'viewCount': '179685',
#   'likeCount': '7449',
#   'commentCount': '251'},
#  {'video_id': 'MbzuFYeq4aU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'IPL Final : Chennai Super Kings vs Gujarat Titans Match Preview ft. Stephen Fleming',
#   'description': 'One final Steph 🗣️📹\n\n#CSKvGT #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-28T11:18:46Z',
#   'viewCount': '88408',
#   'likeCount': '4840',
#   'commentCount': '265'},
#  {'video_id': 'fGHl5k_PyNE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Thank You, Chepauk! - Rewinding the memories of the summer!',
#   'description': "Memories of home that still stand fresh! What's your special moment of the Summer, Makkaley? \n\n#WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-28T08:48:51Z',
#   'viewCount': '131193',
#   'likeCount': '7157',
#   'commentCount': '240'},
#  {'video_id': 'g87iuCiFM0E',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Birthday celebrations of Michael Hussey | Super Birthday #WhistlePodu',
#   'description': 'Hip Hip Hussey! Ofcourse there had to be a cake smash! 🥳\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-27T16:37:41Z',
#   'viewCount': '84930',
#   'likeCount': '4774',
#   'commentCount': '199'},
#  {'video_id': '1QyC0VyxjUA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super couple episode 2 - Devon Conway and Kim Conway',
#   'description': "The Super couple you have come to love, the journey you don't know!\n\nBrand new episode of #SuperCouple ft. Mr and Mrs. Conway 📹🔗\n\n#WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-27T15:22:25Z',
#   'viewCount': '573551',
#   'likeCount': '17418',
#   'commentCount': '574'},
#  {'video_id': 'JNs4p0pk8Ms',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Broken bridge, Dosa, Curd rice and more.. | In Chennai ft. Tushar, Simar and Prashant',
#   'description': 'The broken bridge, some good food and lots of fun 😍\n\n"In Chennai" new episode ft. Tushar, Simar and Prashant out now 📹\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-27T10:45:34Z',
#   'viewCount': '107704',
#   'likeCount': '4692',
#   'commentCount': '136'},
#  {'video_id': 'dsMLIZKIEd8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'I wish i could have batted like Conway - Michael Hussey | Anbuden Diaries Part 2',
#   'description': 'Mr. Cricket break downs on working alongside Rutu-way and more!📹 🙌\n\nFull episode out now 🔗🔽\n\n#WhistlePodu #Yellove 🦁',
#   'publishedAt': '2023-05-27T08:51:32Z',
#   'viewCount': '39634',
#   'likeCount': '2820',
#   'commentCount': '166'},
#  {'video_id': 'QJNsvEta0UI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Reliving the Super King journey - Anbuden Diaries ft. Michael Hussey',
#   'description': "From being a Super King to making lions of all! Here's the Aussie Hussey about his journey with the pride! \n\n#WhistlePodu #Yellove",
#   'publishedAt': '2023-05-26T15:09:00Z',
#   'viewCount': '61496',
#   'likeCount': '3132',
#   'commentCount': '128'},
#  {'video_id': 'iVWyETew2KM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Appreciation for the ground staff ft. Thala MS Dhoni | Anbuden Thanks',
#   'description': 'Anbuden Thala - A mark of respect for the markers and the ground staff who toil hard to make us game ready! 💛📹\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-25T16:42:32Z',
#   'viewCount': '442529',
#   'likeCount': '21284',
#   'commentCount': '784'},
#  {'video_id': '0b6rhoi1pAQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Like father, like son ! 🙌🏏#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-25T15:12:04Z',
#   'viewCount': '12531619',
#   'likeCount': '503444',
#   'commentCount': '634'},
#  {'video_id': 'RF3gM9MUPwk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'First time in Yellove ft. Sisanda Magala | #WhistlePodu',
#   'description': 'Magala narrates the story of his call up to represent the 🦁 and his first experience in Yellove 💛',
#   'publishedAt': '2023-05-25T10:06:06Z',
#   'viewCount': '57647',
#   'likeCount': '3417',
#   'commentCount': '122'},
#  {'video_id': 'FCJyVOtupZg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Masters in Discussion - Anbuden Diaries ft. Eric Simons and Dwayne Bravo',
#   'description': 'Learning from each other and cracking game plans! Watch Eric and Bravo in discussion! 🗣️🎙️\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-24T15:07:05Z',
#   'viewCount': '66184',
#   'likeCount': '3660',
#   'commentCount': '142'},
#  {'video_id': '-zEynAwpLVI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Qualifier Game in Review ft. Ruturaj Gaikwad - #GTvCSK #IPL2023',
#   'description': "The 360* Playoff Narrative with the player of the match! Here's the game in review...\n\n#WhistlePodu #Yellove #IPL2023",
#   'publishedAt': '2023-05-24T10:31:55Z',
#   'viewCount': '99277',
#   'likeCount': '6677',
#   'commentCount': '233'},
#  {'video_id': '_xYIJwAgJ_k',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Gujarat Titans vs Chennai Super Kings Q1 - Post match scenes at the Team Hotel | #GTvCSK',
#   'description': 'We can’t get enough of it! \n\n#IPL2023 #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-24T04:43:45Z',
#   'viewCount': '305081',
#   'likeCount': '17405',
#   'commentCount': '500'},
#  {'video_id': 'as-5cUQfhBk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Qualifier -1 #GTvCSK Match Preview ft. Devon Conway',
#   'description': "With the first qualifier just a few hours away, here's Mr. Consistent with the game plans, home advantage and more! \n\n#WhistlePodu #Yellove",
#   'publishedAt': '2023-05-23T09:28:52Z',
#   'viewCount': '96935',
#   'likeCount': '6382',
#   'commentCount': '414'},
#  {'video_id': 'ss4vpidhoHU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Moeen Ali on his journey with the Pride | Anbuden Diaries',
#   'description': 'Moeen Bhai in awe over our way of things! Watch him narrate his journey with the pride this year so far! \n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-23T06:13:28Z',
#   'viewCount': '79063',
#   'likeCount': '4360',
#   'commentCount': '178'},
#  {'video_id': 'mXm-VjKPd1g',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Raw Version of the roar! 🔥#GTvCSK #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-23T03:31:03Z',
#   'viewCount': '308470',
#   'likeCount': '27848',
#   'commentCount': '258'},
#  {'video_id': 'k-QBfI95DT8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ball Tracking with Mo & Co! 💥#IPL2023 #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-22T16:36:13Z',
#   'viewCount': '398880',
#   'likeCount': '28234',
#   'commentCount': '115'},
#  {'video_id': 'z4fIO1-qF5Q',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Sharpening the blade for the strike! ⚔️🔥#IPL2023 #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-22T15:08:00Z',
#   'viewCount': '205067',
#   'likeCount': '15935',
#   'commentCount': '82'},
#  {'video_id': 'AD75Jds6EfI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Anbuden Diaries ft. Ben Stokes',
#   'description': "Summer Rewind ft. NanBen! Here's Stokesy getting candid about all things cricket! 📹\n\n#WhistlePodu #Yellove 🦁",
#   'publishedAt': '2023-05-22T13:56:24Z',
#   'viewCount': '178362',
#   'likeCount': '9733',
#   'commentCount': '410'},
#  {'video_id': 'mh9Mqqdvs9c',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Golfers Day out ft. Fleming, Hussey, Eric & Santner | Kings Arena',
#   'description': 'Acing the Golfers Day out with the Vaathis and Mitch! ⛳\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-22T05:41:14Z',
#   'viewCount': '68718',
#   'likeCount': '3918',
#   'commentCount': '116'},
#  {'video_id': '6t0tazaQy5U',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'A standout performance' - #DCvCSK Game Review ft. Ruturaj Gaikwad",
#   'description': 'The star of the show narrates the game in review! 📹⏪\n\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-21T12:19:20Z',
#   'viewCount': '65759',
#   'likeCount': '4704',
#   'commentCount': '178'},
#  {'video_id': 'r7X4ww16H68',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Action Plan with Ambati Rayudu - #DCvCSK Match Preview',
#   'description': 'A crucial game is approaching. Get game ready with the preview for our last stand! \n\n#WhistlePodu #Yellove',
#   'publishedAt': '2023-05-20T08:03:45Z',
#   'viewCount': '34835',
#   'likeCount': '2248',
#   'commentCount': '109'},
#  {'video_id': 'D9_FvFWvSAw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'By the nets in monochrome -  Training Compilation | #DCvCSK',
#   'description': 'Bringing out the colours on your feed! \n\n#DCvCSK #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-20T05:59:39Z',
#   'viewCount': '37905',
#   'likeCount': '3292',
#   'commentCount': '225'},
#  {'video_id': '3CGVbrCOrsA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Rutu's Travel Vlog | Safari Times Episode 02 - Chennai to Delhi, 2023",
#   'description': 'In the second episode of Safari times, Ruturaj Gaikwad chats with the fellow Superkings during their travel from Chennai to Delhi for the final league game of the season #WhistlePodu #Yellove',
#   'publishedAt': '2023-05-20T03:58:45Z',
#   'viewCount': '317809',
#   'likeCount': '18102',
#   'commentCount': '537'},
#  {'video_id': 'vKaEjIPEGxc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Moeen Ali reflects on the Summer of 23' so far | Lions upclose",
#   'description': 'Upclose and personal with Ali Bhai on the season so far, the fans support and lots more..!\n\nWatch the full episode 📹🔽\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-19T15:36:47Z',
#   'viewCount': '47932',
#   'likeCount': '2908',
#   'commentCount': '116'},
#  {'video_id': '3hFftuQdwSs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'WhistlePodu Express 2023 Travelogue - The Memories',
#   'description': "A Million memories as we boarded the WhistlePodu Express this year on 29th April! Here's the recap as we look back with #Yellove",
#   'publishedAt': '2023-05-18T10:48:15Z',
#   'viewCount': '121950',
#   'likeCount': '2932',
#   'commentCount': '128'},
#  {'video_id': '2Xh24NockS4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "The Grind Mindset and more - Lion's Up Close ft. Rajvardhan Hangargekar",
#   'description': 'Getting up close and personal about cricket and more… Here’s Rajvardhan! 📹🦁\n\n#WhistlePodu #Yellove 💛',
#   'publishedAt': '2023-05-17T14:30:00Z',
#   'viewCount': '21716',
#   'likeCount': '1678',
#   'commentCount': '47'},
#  {'video_id': 'uhOjJIS5HIQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super Couple Episode 1 - Dwaine and Zilma Pretorius',
#   'description': "We are back to binging our favourite #SuperCouple segment and here's Dwaine and Zilma with their story! \n#WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-17T12:30:46Z',
#   'viewCount': '67009',
#   'likeCount': '3298',
#   'commentCount': '78'},
#  {'video_id': 'wleEunjXJLk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Training through the third eye - SuperCam ft. Mitchell Santner',
#   'description': 'Rewind ⏪ to Mitch’s very first day in the camp this season with a special view 👁️\n\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-16T14:36:18Z',
#   'viewCount': '76753',
#   'likeCount': '4972',
#   'commentCount': '213'},
#  {'video_id': 'OOCfxuEmSCk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Powering up the pace batteries - Anbuden Diaries ft. Bowling Coaches DJ Bravo and Eric Simons',
#   'description': 'Hear it all from the Vaathis behind our pace cartel! \n\n#WhistlePodu #Yellove',
#   'publishedAt': '2023-05-16T11:23:05Z',
#   'viewCount': '52864',
#   'likeCount': '2956',
#   'commentCount': '142'},
#  {'video_id': 'cA-U338hrdI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Last home game whistles - #CSKvKKR match review',
#   'description': 'A lookback at last night as we move back to the drawing board! \n\n#CSKvKKR #WhistlePodu #Yellove',
#   'publishedAt': '2023-05-15T11:32:56Z',
#   'viewCount': '47138',
#   'likeCount': '2882',
#   'commentCount': '150'},
#  {'video_id': 'rFGr1pg5_Uc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Whistles From Chepauk - Episode 7 : Kings vs Knights | #CSKvKKR',
#   'description': 'Last home game and it had to be special with the whistles! 🥳\n\n#CSKvKKR #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-15T10:21:08Z',
#   'viewCount': '21206',
#   'likeCount': '1664',
#   'commentCount': '69'},
#  {'video_id': 'PLg5FgZjVyA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Cherry x Dhool 🫂👕Just like old times 💛#CSKvKKR #WhistlePodu #Yellove 🦁',
#   'description': '',
#   'publishedAt': '2023-05-15T05:15:17Z',
#   'viewCount': '715968',
#   'likeCount': '64005',
#   'commentCount': '271'},
#  {'video_id': '3aOXY3j8YNc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'A night of gratitude and infinite #Yellove #YellorukkumThanks #WhistlePodu 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-14T18:44:27Z',
#   'viewCount': '380239',
#   'likeCount': '21059',
#   'commentCount': '602'},
#  {'video_id': 'g9wXiIJxxEI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Kings vs Kolkata Knight Riders Match Preview with DJ Bravo and Eric Simons | #CSKvKKR',
#   'description': "One final time this league stage @ Anbuden! Here's a special preview with our bowling coaches Eric and DJ Bravo 📹\n\n#CSKvKKR #WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-14T09:55:47Z',
#   'viewCount': '42730',
#   'likeCount': '2649',
#   'commentCount': '126'},
#  {'video_id': 'qocCXT_9cRk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Anbuden Diaries - Chennai Super Kings vs Kolkata Knight Riders | #CSKvKKR',
#   'description': 'Soak into the atmosphere of Anbuden from our eyes in the sky! 📹🚁\n\n#CSKvKKR #WhistlePodu #Yellove 💛🦁',
#   'publishedAt': '2023-05-14T05:39:39Z',
#   'viewCount': '61632',
#   'likeCount': '4616',
#   'commentCount': '177'},
#  {'video_id': '1olMhbW9SOs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Riding the waves! - In Chennai with Dwaine Pretorius and Devon Conway',
#   'description': 'Chennai boys making the waves at Mahabs! \n\n#WhistlePodu #Yellove',
#   'publishedAt': '2023-05-14T02:57:19Z',
#   'viewCount': '347510',
#   'likeCount': '11923',
#   'commentCount': '215'},
#  {'video_id': 'FjsCbmIZlXQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '3..2..1..... 🚀#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-13T13:45:55Z',
#   'viewCount': '335640',
#   'likeCount': '39250',
#   'commentCount': '108'},
#  {'video_id': 'juAF8d1-F78',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Straight into the zone! 🪄#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-13T11:54:10Z',
#   'viewCount': '107418',
#   'likeCount': '10469',
#   'commentCount': '51'},
#  {'video_id': '9u_qRrwyEQI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Kothu Parotta Masterclass with Maheesh Theekshana and Matheesha Pathirana',
#   'description': 'Taking you through the tastes and turns of Kothu Parotta with Maheesh and Matheesha 📹😋\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-13T08:26:30Z',
#   'viewCount': '553329',
#   'likeCount': '13712',
#   'commentCount': '436'},
#  {'video_id': 'RJ8A3mjuKL0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'A closer look at Ajinkya Rahane - Lions Up Close',
#   'description': "Mirroring the Captain Cool and everything under the sun! Here's Ajinkya's unfiltered thoughts! 🦁🆒\n#WhistlePodu #Yellove",
#   'publishedAt': '2023-05-12T13:43:13Z',
#   'viewCount': '84477',
#   'likeCount': '4720',
#   'commentCount': '154'},
#  {'video_id': '3c5hHUIHH54',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Journey of Ambati Rayudu in Yellove | ATR 200*',
#   'description': 'Celebrating ATR’s journey so far by looking back at some of his best moments in Yellove 📹\n\n#whistlepodu #yellove',
#   'publishedAt': '2023-05-11T15:25:10Z',
#   'viewCount': '38049',
#   'likeCount': '2677',
#   'commentCount': '72'},
#  {'video_id': 'NbJ55prgmFg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Whistles From Chepauk - Episode 6 : The Capitals Challenge | #CSKvDC',
#   'description': 'Home Game always brings along a Sea of Yellove at Anbuden 💛\n\nWhistles From Chepauk ft. #CSKvDC🙌',
#   'publishedAt': '2023-05-11T12:32:43Z',
#   'viewCount': '30185',
#   'likeCount': '2185',
#   'commentCount': '77'},
#  {'video_id': '4ED_zduANt4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Kings vs Delhi Capitals - Match Review with Ruturaj Gaikwad',
#   'description': 'Reliving last night’s win with Rocket Raja 📹\n\n#CSKvDC #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-11T09:44:59Z',
#   'viewCount': '58101',
#   'likeCount': '4092',
#   'commentCount': '114'},
#  {'video_id': 'AfPjAWSGQg4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ravindra Jadeja  - Player of the Match - #CSKvDC Chepauk, 2023',
#   'description': 'Spinning and Winning! That’s the trick! 🪄\n#CSKvDC #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-11T05:11:02Z',
#   'viewCount': '408739',
#   'likeCount': '14429',
#   'commentCount': '324'},
#  {'video_id': '32gL5pW-_-k',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '10 May 2023',
#   'description': '',
#   'publishedAt': '2023-05-10T13:00:39Z',
#   'viewCount': '206643',
#   'likeCount': '20607',
#   'commentCount': '61'},
#  {'video_id': 'BwXrq-IXqf0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Kings vs Delhi Capitals Match Preview with Mike Hussey',
#   'description': 'The Capital Clash at Anbuden previewed by Mr. Cricket! 📹\n\n#CSKvDC #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-10T10:00:59Z',
#   'viewCount': '47922',
#   'likeCount': '3348',
#   'commentCount': '161'},
#  {'video_id': 'sCZHENnY7zY',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super Kings felicitates Bomman, Bellie & Oscar winning director Kartiki Gonsalves',
#   'description': 'Roars of appreciation to the team that won our hearts! 👏\n\nSo good to host Bomman, Bellie and the filmmaker Kartiki Gonsalves! 🐘\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-10T07:57:34Z',
#   'viewCount': '97963',
#   'likeCount': '8315',
#   'commentCount': '184'},
#  {'video_id': 'WIvbZUlxepE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Man catches Everything!🧤#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-10T04:58:28Z',
#   'viewCount': '5820739',
#   'likeCount': '231725',
#   'commentCount': '312'},
#  {'video_id': 'tzIa2UaWB7I',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Beginning with a BANG! Ali Bhai on attack mode! #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-08T13:30:05Z',
#   'viewCount': '175450',
#   'likeCount': '15027',
#   'commentCount': '31'},
#  {'video_id': 'FFMyN80W4a4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'RutuWay all the way! | Anbuden Diaries ft. Ruturaj and Conway',
#   'description': "Trust the super duo for racy starts! Here's a peak into their dynamics on and off field! 🦁🤝🏻\n\n#WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-08T12:45:09Z',
#   'viewCount': '95915',
#   'likeCount': '6791',
#   'commentCount': '214'},
#  {'video_id': 'yaDmYd_S3sY',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Whistles From Chepauk - Episode 5 : The El Clasico Edition',
#   'description': "After 4777 days, Anbuden had a reason to rejoice! Here's the ElClasico edition of the Whistles from Chepauk! \n\n#WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-07T12:07:34Z',
#   'viewCount': '53141',
#   'likeCount': '3522',
#   'commentCount': '124'},
#  {'video_id': 'tTGYIEgne0k',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Kings vs Mumbai Indians - Match Review with Deepak Chahar  #CSKvMI',
#   'description': 'Cherry Picking his favourite moments from the game last night! 🦁\n\n#CSKvMI #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-07T09:09:42Z',
#   'viewCount': '68297',
#   'likeCount': '4329',
#   'commentCount': '144'},
#  {'video_id': 'f5ZdZRGLITI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Matheesha Pathirana -  Player of the Match - #CSKvMI Chepauk, 2023',
#   'description': '🗣️🎙️Words from The Man of the Moment! \n\n#CSKvMI #WhistlePodu #Yellove 🦁💛 @IndiaCementsLtd',
#   'publishedAt': '2023-05-07T06:25:59Z',
#   'viewCount': '1585558',
#   'likeCount': '34588',
#   'commentCount': '658'},
#  {'video_id': 'gsnoEoyZ-q8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chinna Thala at Anbuden - Trip down the memory lane ft. Suresh Raina',
#   'description': "They say memories bring back memories! Rightly said! :') \n\n#WhistlePodu #Yellove @IndiaCementsLtd",
#   'publishedAt': '2023-05-06T09:23:41Z',
#   'viewCount': '118944',
#   'likeCount': '9165',
#   'commentCount': '345'},
#  {'video_id': '57oNWb4w3VU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'El Clasico is back home! -  #CSKvMI Match Preview ft. Maheesh Theekshana',
#   'description': "A day and night fight night ahead! Here's Theekshana giving you the lion's insight! 💪🏻\n\n#CSKvMI #WhistlePodu #Yellove 🦁💛 @tvseurogrip5292",
#   'publishedAt': '2023-05-06T08:27:14Z',
#   'viewCount': '27994',
#   'likeCount': '2377',
#   'commentCount': '158'},
#  {'video_id': 'upSADORbhYM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'El Clasico Training Day - #CSKvMI',
#   'description': 'Emotions are high as we bring the #ElClasico clash home! 🦁\n\n#CSKvMI #WhistlePodu #Yellove 💛',
#   'publishedAt': '2023-05-06T07:27:08Z',
#   'viewCount': '111051',
#   'likeCount': '6590',
#   'commentCount': '335'},
#  {'video_id': 'bqv7uphvjHU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Shot Mo-chi! 🤩#CSKvMI #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-05T16:04:25Z',
#   'viewCount': '315488',
#   'likeCount': '18737',
#   'commentCount': '53'},
#  {'video_id': 'J_CHunEwzOw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Just can't skip this! 🥳🤩#CSKvMI #WhistlePodu #Yellove 🦁💛",
#   'description': '',
#   'publishedAt': '2023-05-05T12:43:24Z',
#   'viewCount': '2450809',
#   'likeCount': '143617',
#   'commentCount': '265'},
#  {'video_id': '5SKwEBmpC5U',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Passion and Belief - First Time in Yellove ft. Akash Singh',
#   'description': "A new run up began this season and here's Akash narrating his emotions of his #FirstTimeInYellove \n\n#whistlepodu #Yellove",
#   'publishedAt': '2023-05-05T10:50:03Z',
#   'viewCount': '29528',
#   'likeCount': '2501',
#   'commentCount': '126'},
#  {'video_id': 'y6bLkHmZrQ8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Tapping into the fan pulse with namma Super Kings!#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-04T16:43:31Z',
#   'viewCount': '172627',
#   'likeCount': '13192',
#   'commentCount': '50'},
#  {'video_id': '3U_NRKIeN1Y',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ace by the Pacer!🏌🏻#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-05-04T13:44:45Z',
#   'viewCount': '3655056',
#   'likeCount': '156898',
#   'commentCount': '213'},
#  {'video_id': 'gmlvvur17qQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Contributing to the team is my main goal - Lions upclose ft. Ruturaj Gaikwad',
#   'description': 'Getting better with every game! Hear our Rutu as he breaks down his approach to the sport! \n\n#WhistlePodu #Yellove #IPL2023',
#   'publishedAt': '2023-05-04T13:39:27Z',
#   'viewCount': '64016',
#   'likeCount': '4924',
#   'commentCount': '252'},
#  {'video_id': '3IpaFRIs4oo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Spinners Day Out - #LSGvCSK Match Review',
#   'description': 'As the rains washed out last evening, the Super Kings had a spin storm to display! Watch the game review as we head home! \n\n#WhistlePodu #Yellove @gulfoilindia4337',
#   'publishedAt': '2023-05-04T07:34:56Z',
#   'viewCount': '54039',
#   'likeCount': '3563',
#   'commentCount': '156'},
#  {'video_id': 'y_gyCB_dRMo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Clash of the Supers - #LSGvCSK Match Preview',
#   'description': "A test of skills awaits us at the Ekana. Here's the preview to get up the excitement! \n\n#LSGvCSK #WhistlePodu #Yellove",
#   'publishedAt': '2023-05-03T06:46:43Z',
#   'viewCount': '45531',
#   'likeCount': '3439',
#   'commentCount': '199'},
#  {'video_id': 'Swr7QWKme70',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'Being the X Factor...' - Lion's Upclose Ft. Dwaine Pretorius",
#   'description': 'Hear out Dwaine Pretorius break down his game, his learnings and how he fits into the Super Kings scheme of things! \n\n#WhistlePodu #Yellove #IPL2023',
#   'publishedAt': '2023-05-02T14:52:08Z',
#   'viewCount': '23157',
#   'likeCount': '2141',
#   'commentCount': '163'},
#  {'video_id': 'Rnd5dY93Qz8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super Cam - FPV of the Super Practice ft. Ruturaj Gaikwad',
#   'description': 'Step in to the mind of the Rocket Raja and see the grind real time! \n\n#WhistlePodu #Yellove',
#   'publishedAt': '2023-05-02T09:06:43Z',
#   'viewCount': '194745',
#   'likeCount': '12428',
#   'commentCount': '368'},
#  {'video_id': '93VoZeEREwM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Devon Conway Speech - Player of the Match | #CSKvPBKS',
#   'description': 'Carried his bat through the innings! Hear from the man himself 💛\n\n#CSKvPBKS #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-05-01T12:45:00Z',
#   'viewCount': '32544',
#   'likeCount': '2746',
#   'commentCount': '96'},
#  {'video_id': 'p1iLKSUQl7c',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Post Match Review - Chennai Super Kings vs Punjab Kings | #CSKvPBKS',
#   'description': "Here's how the clash of the Kings unfolded! 📹\n\n#CSKvPBKS #WhistlePodu #Yellove 🦁💛",
#   'publishedAt': '2023-05-01T08:21:48Z',
#   'viewCount': '35109',
#   'likeCount': '2421',
#   'commentCount': '227'},
#  {'video_id': 'bTgfjK2f4wk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'We will keep the roar going just like your support has been throughout! 💛#WhistlePoduExpress',
#   'description': '',
#   'publishedAt': '2023-04-30T15:12:17Z',
#   'viewCount': '206204',
#   'likeCount': '21679',
#   'commentCount': '108'},
#  {'video_id': 'hXpd9BhNwS8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'WhistlePodu Express | Kanyakumari to Anbuden - #CSKvPBKS',
#   'description': 'An eventful journey that led to one destination: Anbuden 🦁🏟️\n#WhistlePoduExpress #Yellove 💛',
#   'publishedAt': '2023-04-30T09:27:49Z',
#   'viewCount': '14850',
#   'likeCount': '1591',
#   'commentCount': '86'},
#  {'video_id': 'xDmrXFdN7bQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Kings vs Punjab Kings Match Preview with Tushar Deshpande | #CSKvPBKS',
#   'description': "Here's Tu what we can expect from our first day game of the season with \nTushar 📹 #WhistlePodu #Yellove",
#   'publishedAt': '2023-04-30T05:44:42Z',
#   'viewCount': '31012',
#   'likeCount': '2529',
#   'commentCount': '221'},
#  {'video_id': '1d_0ntaz6j0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Having Dhoni as a leader is very special for me - Devon Conway | Lions upclose',
#   'description': 'The Den experience, playing under Thala, the Chennai crowd and much more! \n\n#whistlepodu #yellove #cskvpbks #devonconway',
#   'publishedAt': '2023-04-30T03:23:40Z',
#   'viewCount': '216095',
#   'likeCount': '8749',
#   'commentCount': '266'},
#  {'video_id': 'IDA3tvXQTbs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Jaddu’s fielding masterclass with Sena \U0001faf6💛  #WhistlePodu #Yellove 🦁',
#   'description': '',
#   'publishedAt': '2023-04-29T17:23:21Z',
#   'viewCount': '6296247',
#   'likeCount': '356360',
#   'commentCount': '432'},
#  {'video_id': '1sT-mWQF5MA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Ravindra Jadeja's dose of magic through the years | 150 IPL game in Yellove",
#   'description': "As Jaddu stepped on to field in Yellove for the 150th time, Here's a dose of magic through the years! ✨\n\n#WhistlePodu #Yellove 🦁💛 @imjadeja",
#   'publishedAt': '2023-04-28T15:20:38Z',
#   'viewCount': '36525',
#   'likeCount': '3306',
#   'commentCount': '186'},
#  {'video_id': 'ZDoZWorU5YA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Rajasthan Royals vs Chennai Super Kings - Match Review | #RRvCSK',
#   'description': "Taking it in stride and moving forward, here's a look back at last night! \n\n#RRvCSK #WhistlePodu #Yellove 💛🦁",
#   'publishedAt': '2023-04-28T11:20:55Z',
#   'viewCount': '42342',
#   'likeCount': '2795',
#   'commentCount': '168'},
#  {'video_id': 'ydHsLlarpDc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '#RRvCSK at Jaipur, brings back some memories doesn’t it? 😃#WhistlePodu #Yellove 💛🦁',
#   'description': '',
#   'publishedAt': '2023-04-27T10:01:10Z',
#   'viewCount': '382815',
#   'likeCount': '37242',
#   'commentCount': '103'},
#  {'video_id': 'dVfv487Kx2k',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Plug in your 🎧 for 💥 ft. Shaik Rasheed! #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-27T07:13:51Z',
#   'viewCount': '252075',
#   'likeCount': '22843',
#   'commentCount': '89'},
#  {'video_id': 'Y4dGk8R2OJw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Rajasthan Royals vs Chennai Super Kings Match Preview with Shivam Dube | #RRvCSK',
#   'description': "Here's what Shivam Dube believes today's Royal clash would be like🙌 #RRvCSK #whistlepodu #yellove",
#   'publishedAt': '2023-04-27T06:00:17Z',
#   'viewCount': '77887',
#   'likeCount': '5290',
#   'commentCount': '223'},
#  {'video_id': 'wo04Ft7rNf4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Birthday today; Matchday tomorrow! And some candid POV in between! 📹#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-26T18:04:17Z',
#   'viewCount': '202114',
#   'likeCount': '21361',
#   'commentCount': '66'},
#  {'video_id': 'xiPKofKE1vg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Akash Singh birthday celebrations in Jaipur | #RRvCSK',
#   'description': 'Akash Singh embracing the Super Kings Birthday rituals at Jaipur 🥳 #whistlepodu #yellove #Superbirthday',
#   'publishedAt': '2023-04-26T15:54:38Z',
#   'viewCount': '192483',
#   'likeCount': '11220',
#   'commentCount': '319'},
#  {'video_id': 'V9q-egmwWO8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ready Madi Adi - A Super Strong Fan Anthem ft, Sunfeast Supermilk',
#   'description': "Naanga READY than… Finger MADI than…Ippo Stronga Whistle ADI than!\nHere's Sunfeast Supermilk’s groovy fan anthem for CSK Super Fans!!\n\n#SunfeastSupermilk #StrongaaWhistlePodu",
#   'publishedAt': '2023-04-26T05:32:39Z',
#   'viewCount': '48783',
#   'likeCount': '4851',
#   'commentCount': '125'},
#  {'video_id': '18K3eMFX0UQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '📹 Touching Down the Pink City with 😃😀#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-26T05:12:11Z',
#   'viewCount': '248150',
#   'likeCount': '30345',
#   'commentCount': '160'},
#  {'video_id': 'QNjmoOpsKI0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "The emotion attached to Thala Dhoni's bat | Lions upclose ft. Shaik Rasheed",
#   'description': "Thala Dhoni's bat, his Father's reaction to him being picked up by the Super Kings, Conversations with VVS Laxman and more.. #whistlepodu #yellove",
#   'publishedAt': '2023-04-25T14:05:35Z',
#   'viewCount': '68713',
#   'likeCount': '3848',
#   'commentCount': '126'},
#  {'video_id': 'RvyXWBuTq78',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Akash Singh reflects on the incredible win at Eden Gardens | #KKRvCSK Match Review',
#   'description': 'The tales of an incredible win 🙌 Hear it from our Young Gun himself 🗣️\n\n#KKRvCSK #WhistlePodu #Yellove #IPL2023',
#   'publishedAt': '2023-04-24T15:41:47Z',
#   'viewCount': '62613',
#   'likeCount': '4251',
#   'commentCount': '120'},
#  {'video_id': 'g7IKEDSeOlc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Modest Ajju on his knock last night 💛#KKRvCSK #WhistlePodu #Yellove 🦁',
#   'description': '',
#   'publishedAt': '2023-04-24T13:07:28Z',
#   'viewCount': '255129',
#   'likeCount': '27797',
#   'commentCount': '125'},
#  {'video_id': 'lN8BIsMtpF4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'To Top off Speedy Singh’s spell yesterday! 📹#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-24T13:04:11Z',
#   'viewCount': '201470',
#   'likeCount': '15189',
#   'commentCount': '27'},
#  {'video_id': 'WoGr30SxotQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Your Anbuden experience is on us! Participate and win Free #CSKvPBKS Match Tickets  #IPL2023 🦁',
#   'description': '',
#   'publishedAt': '2023-04-23T08:53:56Z',
#   'viewCount': '141662',
#   'likeCount': '8732',
#   'commentCount': '40'},
#  {'video_id': 'ucDjKyRYGrg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super Sunday Blockbuster | #KKRvCSK Match Preview',
#   'description': "Here's what you can expect from tonight's clash against the Knight Riders 💪 #whistlepodu #yellove #kkrvcsk #IPL2023 #CSK",
#   'publishedAt': '2023-04-23T08:15:19Z',
#   'viewCount': '114367',
#   'likeCount': '5454',
#   'commentCount': '118'},
#  {'video_id': '7fHTQv8h35s',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Home Whistles Roaring loud! - Whistles From Chepauk Vol.3',
#   'description': 'The Friday home game against the Sunrisers was nothing short of a spectacle to behold! Hear it from the fans!',
#   'publishedAt': '2023-04-23T06:17:28Z',
#   'viewCount': '31104',
#   'likeCount': '2642',
#   'commentCount': '78'},
#  {'video_id': 'MiY0kit0Q54',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Everywhere we go... Roar and Shine, We are Texas Super Kings! 🦁⭐ #WhistleForTexas',
#   'description': 'Revealing the new look of the Texas Super Kings logo, our representation in the Major League Cricket, USA!',
#   'publishedAt': '2023-04-22T15:29:53Z',
#   'viewCount': '98748',
#   'likeCount': '6359',
#   'commentCount': '158'},
#  {'video_id': 'TNUrTntMOR4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"Blessed to watch Rutu-Conway bat!" - Maheesh Theekshana | #CSKvSRH Match Review',
#   'description': 'Incase you missed it, here’s Theekshana on the turn of events last night against the Sunrisers! 🦁\n\n#CSKvSRH #WhistlePodu #Yellove #IPL2023 💛 @gulfoilindia4337',
#   'publishedAt': '2023-04-22T14:45:10Z',
#   'viewCount': '96743',
#   'likeCount': '4700',
#   'commentCount': '128'},
#  {'video_id': 'zRdywsfPowU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Battle of the South - #CSKvSRH Match Preview ft. Eric Simmons',
#   'description': 'A sit down with coach Eric as he walks us through the home game prep for the Battle of the South! 📹\n\n#CSKvSRH #WhistlePodu #Yellove 🦁 #TVSEurogrip',
#   'publishedAt': '2023-04-21T10:49:33Z',
#   'viewCount': '41519',
#   'likeCount': '3494',
#   'commentCount': '183'},
#  {'video_id': 'xvaJyZUz5kU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Learning from Dad, Thala and within | Lions Up Close - Ft. Shivam Dube',
#   'description': 'Story Time! Singam Shivam gets candid in conversation on what goes into his prep mindset! \n\n#whistlepodu #Yellove',
#   'publishedAt': '2023-04-21T08:20:07Z',
#   'viewCount': '107940',
#   'likeCount': '5933',
#   'commentCount': '187'},
#  {'video_id': 'arqEP86T4kY',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Super King's Day out IN CHENNAI Episode 1 ft. Rasheed, Rajvardhan & Nishant",
#   'description': 'IN CHENNAI features our Superkings visiting popular places of Chennai and exploring the city! The first episode features Rajvardhan Hangargekar, Nishant Sindhu & Shaik Rasheed #whistlepodu #yellove',
#   'publishedAt': '2023-04-20T13:30:01Z',
#   'viewCount': '130426',
#   'likeCount': '6293',
#   'commentCount': '134'},
#  {'video_id': 'qedMFDc8RiE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Fifteen Years Since! - Memories of The First Roar ft. Pride of 2008',
#   'description': 'After all this time? Always! The Pride of 2008 recollect in nostalgia! \n\n#whistlepodu #yellove',
#   'publishedAt': '2023-04-19T17:10:53Z',
#   'viewCount': '107508',
#   'likeCount': '5072',
#   'commentCount': '151'},
#  {'video_id': 'u4XeraUoy0o',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Super Star and the Super King! 😎🔥#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-19T07:16:46Z',
#   'viewCount': '809767',
#   'likeCount': '56681',
#   'commentCount': '139'},
#  {'video_id': 'AXf8V7BGcTk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Matheesha Pathirana reflects on his last over finish | RCB vs CSK Review',
#   'description': 'The Wonder Slinger Matheesha reviews the high octane bangalore challenge!\n\n#RCBvsCSK #WhistlePodu #Yellove  🦁💛',
#   'publishedAt': '2023-04-18T12:56:34Z',
#   'viewCount': '287872',
#   'likeCount': '11196',
#   'commentCount': '312'},
#  {'video_id': 'vyNdxDJAGlE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The streets know and whistle! 🥳#RCBvCSK #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-17T13:12:36Z',
#   'viewCount': '161500',
#   'likeCount': '16125',
#   'commentCount': '54'},
#  {'video_id': 'QTmv2tm2rzs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Champion looks back at his Bangalore Days! #RCBvCSK #WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-17T10:33:58Z',
#   'viewCount': '446431',
#   'likeCount': '37312',
#   'commentCount': '85'},
#  {'video_id': 'ru5CSzUKISM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'An Electric Crowd to entertain!' | #RCBvCSK Match Preview ft. Moeen Ali",
#   'description': 'Take a closer look at the Challenge that awaits us tonight with Moeen Ali! \nGet. Set. #WhistlePodu 🦁💛',
#   'publishedAt': '2023-04-17T07:12:20Z',
#   'viewCount': '89242',
#   'likeCount': '5511',
#   'commentCount': '343'},
#  {'video_id': 'StkVy1VFNuI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The comeback story of Tushar Deshpande | Anbuden Diaries',
#   'description': 'In the next episode of Anuden Diaries Tushar Deshpande talks about the season so far #whistlepodu #Yellove',
#   'publishedAt': '2023-04-17T04:52:25Z',
#   'viewCount': '36261',
#   'likeCount': '2684',
#   'commentCount': '102'},
#  {'video_id': 'JwKjneYoSsw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Surprise Run-ins with the speedster! 📹#WhistlePodu #Yellove 🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-15T15:58:25Z',
#   'viewCount': '414827',
#   'likeCount': '38853',
#   'commentCount': '135'},
#  {'video_id': 'mwz3rMng1Hc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Great to be back in Chennai | Anbuden Diaries ft. Eric Simons',
#   'description': 'A sit down conversation with our coach Eric! #WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-04-15T11:46:47Z',
#   'viewCount': '24575',
#   'likeCount': '2091',
#   'commentCount': '79'},
#  {'video_id': 'lL1Xebpm4yU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chithirai Super Kondattam - Tamil New Year Celebrations ft. The Super Kings',
#   'description': 'Celebrate this Tamil New Year in the traditional style imagined with the Super Kings! Find more reasons to celebrate at www.chennaisuperkings.com\n\n#whistlepodu #yellove',
#   'publishedAt': '2023-04-14T13:54:55Z',
#   'viewCount': '85381',
#   'likeCount': '6182',
#   'commentCount': '171'},
#  {'video_id': '_nv3DgM7ipU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Whistle From Chepauk - Episode 2 | CSKvRR - 12th April, 2023',
#   'description': 'It rained Yellove the other night with Chennai rallying together to Whistle From Chepauk! While you watch the superfan emotions in display, make sure you register and display yours on www.chennaisuperkings.com \n\n#whistlepodu #yellove',
#   'publishedAt': '2023-04-14T11:39:58Z',
#   'viewCount': '21842',
#   'likeCount': '1887',
#   'commentCount': '71'},
#  {'video_id': 'ld1eHFTR87k',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Thala Thunder! - #CSKvRR Post Match Review',
#   'description': "As we move forward from a nail biting thriller, here's our post match review incase you missed all the action! \n\n#WhistlePodu  #Yellove",
#   'publishedAt': '2023-04-13T13:51:30Z',
#   'viewCount': '57890',
#   'likeCount': '3845',
#   'commentCount': '212'},
#  {'video_id': 'RS60IHtnQTM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Thala 200* | MS Dhoni Felicitated for leading CSK in 200 IPL Games | IPL 2023',
#   'description': 'MS Dhoni felicitated for leading Chennai Super Kings in a record 200 games in IPL before the CSK v RR match.',
#   'publishedAt': '2023-04-12T15:32:41Z',
#   'viewCount': '76400',
#   'likeCount': '5350',
#   'commentCount': '169'},
#  {'video_id': 'nmmVTsvr1mU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Looking forward to enjoy the huge yellow crowd! - CSKvRR Match Preview ft. Mike Hussey',
#   'description': 'Breaking down the battle plan with our batting coach Mike Hussey. Watch and get set to #WhistlePodu from Anbuden!',
#   'publishedAt': '2023-04-12T10:27:32Z',
#   'viewCount': '58721',
#   'likeCount': '4414',
#   'commentCount': '216'},
#  {'video_id': '_K8aUftJPPs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Baahubali BTS 💥#WhistlePodu #Yellove🦁💛',
#   'description': '',
#   'publishedAt': '2023-04-11T13:42:51Z',
#   'viewCount': '189466',
#   'likeCount': '13989',
#   'commentCount': '73'},
#  {'video_id': '-Yq6Oe63SUw',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'MI vs CSK Match review with Debutant Sisanda Magala | #MIvCSK #WhistlePodu',
#   'description': "Hear it from Sisanda how the El Clasico turned out to be! 🥳\n\nHere's the Match Review 📹➡️ \n\n#WhistlePodu #Yellove",
#   'publishedAt': '2023-04-09T11:58:40Z',
#   'viewCount': '134000',
#   'likeCount': '7153',
#   'commentCount': '182'},
#  {'video_id': 'DHcO3jnGDXk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "#ChinnaThala's reaction at the end summed up!💛\U0001f979#WhistlePodu #Yellove 🦁💛",
#   'description': '',
#   'publishedAt': '2023-04-09T04:36:08Z',
#   'viewCount': '401027',
#   'likeCount': '46958',
#   'commentCount': '234'},
#  {'video_id': 'vZzEz5W9TZ0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '#MIvCSK Match Preview with the Champion DJ Bravo | #WhistlePodu',
#   'description': 'Embracing the challenge ahead! Watch the bowling vaathi Bravo share his thoughts ahead of the #MIvCSK matchup! 🦁🎙️\n\n#WhistlePodu #Yellove 🦁💛',
#   'publishedAt': '2023-04-08T07:35:41Z',
#   'viewCount': '91597',
#   'likeCount': '6285',
#   'commentCount': '248'},
#  {'video_id': 'ngIDoq6AwXA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Wankhede memories with Ajinkya Rahane | #MIvCSK #WhistlePodu',
#   'description': 'On the eve of the MI vs CSK encounter, Local boy Ajinkya Rahane shares his memories of playing at the Wankhede Stadium #Yellove #AjinkyaRahane',
#   'publishedAt': '2023-04-08T04:28:29Z',
#   'viewCount': '62263',
#   'likeCount': '4752',
#   'commentCount': '235'},
#  {'video_id': 'N7vqIztpMqw',
# ...
#   'commentCount': '64'},
#  {'video_id': 'IgFSWYxoVIo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'The Real Greatest of All Time',
#   'description': "On the 12th anniversary of our first outing at Chepauk, here's to the GOAT, the real GOAT! #WhistlePodu #Yellove #SuperFans 🦁💛",
#   'publishedAt': '2020-04-23T13:32:01Z',
#   'viewCount': '230283',
#   'likeCount': '14529',
#   'commentCount': '504'},
#  {'video_id': 'm3kXp7V6dr8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"You\'ve never seen my anger till now beta!" Dhoni to Kuldeep',
#   'description': 'Video Courtesy: Jatin Sapru',
#   'publishedAt': '2020-04-23T07:48:39Z',
#   'viewCount': '5976772',
#   'likeCount': '193221',
#   'commentCount': '2000'},
#  {'video_id': '6fkmKWSBXz0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Faf du Plessis wonders which actor should play him in a movie',
#   'description': "#Fafulous plays Dumb Charades for the first time and it's hilarious #AnbuDenLions 🦁💛",
#   'publishedAt': '2020-04-22T05:51:42Z',
#   'viewCount': '84783',
#   'likeCount': '4312',
#   'commentCount': '137'},
#  {'video_id': 'f-6V_mrjjYQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "CSK Physio Tommy Simsek's favourite yellove moments",
#   'description': 'His No.1 moment has stumped us with super logic! 😂 #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-21T15:49:12Z',
#   'viewCount': '10677',
#   'likeCount': '767',
#   'commentCount': '26'},
#  {'video_id': 'eJbvTyVgV3o',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Raina narrates FUNNY incident with Doug Bollinger',
#   'description': '#ChinnaThala on being the first to congratulate the bowlers after a wicket fall and an unforgettable encounter with Douggie Bollinger! #AnbuDenLions',
#   'publishedAt': '2020-04-21T13:22:56Z',
#   'viewCount': '48442',
#   'likeCount': '1921',
#   'commentCount': '58'},
#  {'video_id': '_0Db1n9dIqQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Dhoni riding a bike around his house with Ziva during lockdown',
#   'description': '#Thala #Dhoni #WhistlePodu',
#   'publishedAt': '2020-04-20T15:40:19Z',
#   'viewCount': '72752',
#   'likeCount': '6274',
#   'commentCount': '50'},
#  {'video_id': 'FKpO-pIK_QI',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Bravo sings a song for Dhoni',
#   'description': "Champion's next song is for 'his brudah, his brudah from anodah muddah' - MS Dhoni No.7! 😍🦁💛 #AnbuDenLions #WhistlePodu",
#   'publishedAt': '2020-04-20T13:40:28Z',
#   'viewCount': '141945',
#   'likeCount': '16979',
#   'commentCount': '297'},
#  {'video_id': 'JBCsm6Hwjm8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "The incredible backstory behind Badrinath's Dharamshala Fifty",
#   'description': 'Mr Dependable S Badrinath picks his favourite #yellove moment. He fittingly nominates our Super Physio Tommy Simsek to pick his fav. #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-20T07:45:24Z',
#   'viewCount': '8215',
#   'likeCount': '521',
#   'commentCount': '23'},
#  {'video_id': 'EjQSljuDtqE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Yellove at First Sight',
#   'description': 'On this day twelve summers ago, the first pride entered the field in glorious #yellove. There have been many a firsts that were nothing but #super. It was truly #YelloveAtFirstSight! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-19T17:15:57Z',
#   'viewCount': '27591',
#   'likeCount': '3085',
#   'commentCount': '72'},
#  {'video_id': 'MqwdRxlb0rc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'L Balaji picks his favourite CSK moments',
#   'description': 'How can we ever get over that sensational hat-trick in a 5fer twelve summers ago?! Nominated next is Mr.Dependable S Badrinath! #WhistlePodu #Yellove #MyIPLMoment 🦁💛',
#   'publishedAt': '2020-04-19T08:44:46Z',
#   'viewCount': '11335',
#   'likeCount': '911',
#   'commentCount': '39'},
#  {'video_id': 'jlOpcxte51Q',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"Amazing..to play with a guy like MS..." Albie Morkel on Dhoni\'s Dharamshala innings',
#   'description': "Albie relives that incredible match the men in #yellove pulled off ten summers ago and how they 'almost died 7 times' the following day during a road-trip! #AnbuDenLions",
#   'publishedAt': '2020-04-18T17:17:29Z',
#   'viewCount': '72090',
#   'likeCount': '3024',
#   'commentCount': '113'},
#  {'video_id': 'uv33jrFB-DU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Sam Curran learns Tamil...oh wait...looks like he already knows quite a bit',
#   'description': 'Our #KadaiKuttySingam surprised us with #WhistlePodu, eagerly asked what his nickname meant and learnt a few vitally super words in Thamizh! #AnbuDenLions 🦁💛',
#   'publishedAt': '2020-04-17T15:30:07Z',
#   'viewCount': '1969780',
#   'likeCount': '96635',
#   'commentCount': '2455'},
#  {'video_id': 'NYafqFImTBo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Mike Hussey's favourite CSK Moments",
#   'description': "Faf's 2018 Q1 special and #Thala Dhoni's Dharamshala finish. #WhistlePodu #Yellove",
#   'publishedAt': '2020-04-17T12:11:51Z',
#   'viewCount': '19689',
#   'likeCount': '1730',
#   'commentCount': '54'},
#  {'video_id': 'ffro7DoAOyA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Shardul Thakur's truly heartwarming words on the IPL 2019 Final",
#   'description': '#AnbuDenLions #WhistlePodu #Yellove',
#   'publishedAt': '2020-04-16T14:54:37Z',
#   'viewCount': '20761',
#   'likeCount': '1460',
#   'commentCount': '108'},
#  {'video_id': 'V6K5o9OOh2E',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Shane Watson answers what's the one thing that's different in CSK compared to the other teams",
#   'description': '#AnbuDenLions #WhistlePodu',
#   'publishedAt': '2020-04-16T07:52:07Z',
#   'viewCount': '199139',
#   'likeCount': '7905',
#   'commentCount': '255'},
#  {'video_id': '0BQ2-fubZnE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Faf du Plessis' favourite CSK moments",
#   'description': "Faf has taken Chinna Thala's #MyIPLMoment challenge and mentions quite a few legendary ones. But we are not gonna let him discount his incredible 67* off 42 to take us Fafulously into the 2018 Final! :') The baton now passes on to Mr. Cricket Mike Hussey! #WhistlePodu",
#   'publishedAt': '2020-04-16T03:56:44Z',
#   'viewCount': '72079',
#   'likeCount': '5707',
#   'commentCount': '129'},
#  {'video_id': 'xwOwv_3STLs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Ziva wants to hug Papa Dhoni during the match',
#   'description': '#OnceUpOnAWhistle, in fact exactly two summers ago, when #Thala Dhoni was in the middle of the epic #KXIPvCSK match at Mohali, little Ziva had Papa cravings! This is full of #Yellove! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-15T16:41:38Z',
#   'viewCount': '229961',
#   'likeCount': '8678',
#   'commentCount': '74'},
#  {'video_id': 'gzI0eSGPqkE',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"They used to call me Poona (Mr. Cat Eyes)" - Murali Vijay',
#   'description': '#WhistlePodu #AnbuDenLions',
#   'publishedAt': '2020-04-15T12:49:23Z',
#   'viewCount': '36389',
#   'likeCount': '1516',
#   'commentCount': '65'},
#  {'video_id': 'RpgpTtW1LWU',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Suresh Raina loves Munbe Vaa, sings Inkem Inkem and talks about his yellow Porsche',
#   'description': 'Munbe Vaa, why Suriya Sivakumar is his favourite actor, a cute rendition of Inkem Inkem, sleeping like a baby after Rasam Rice & Curd Rice and the priceless look on his face when he sees his car! #ChinnaThala #AnbuDenLions #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-15T05:53:55Z',
#   'viewCount': '111230',
#   'likeCount': '5565',
#   'commentCount': '123'},
#  {'video_id': 'j4dAXlvZ0Kk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Sam Curran plays table tennis with himself with both the hands',
#   'description': "That's #KadaiKuttySingam paddling in tandem with namma song with superb ambidexterity! #WhistlePodu 🦁💛",
#   'publishedAt': '2020-04-14T16:44:10Z',
#   'viewCount': '654141',
#   'likeCount': '36959',
#   'commentCount': '664'},
#  {'video_id': 'uNSrPSgIoP4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'A bit of blood is not gonna stop me!' - Shane Watson",
#   'description': 'Watto Man opens up about his EPIC innings in IPL 2019 Final. #AnbuDenLions #WhistlePodu',
#   'publishedAt': '2020-04-14T09:17:06Z',
#   'viewCount': '112003',
#   'likeCount': '6891',
#   'commentCount': '246'},
#  {'video_id': 'BXFQVBDmTPM',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Shardul Thakur is called Mr Google by his India teammates',
#   'description': '#AnbuDenLions #WhistlePodu',
#   'publishedAt': '2020-04-13T13:18:11Z',
#   'viewCount': '59195',
#   'likeCount': '2775',
#   'commentCount': '77'},
#  {'video_id': 'QIW1KxKjjs0',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'Hayden's Mongoose innings is my all-time favourite!' - Suresh Raina",
#   'description': "Chinna Thala responds to Haydos' challenge and reveals his favourite IPL moment.",
#   'publishedAt': '2020-04-13T08:08:41Z',
#   'viewCount': '52676',
#   'likeCount': '4563',
#   'commentCount': '37'},
#  {'video_id': 'LV2Q6pcMs0o',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "'Dhoni's Dharamshala innings is my favourite!' - Matthew Hayden",
#   'description': 'Adores the Dharamshala innings and his catch off Pollard in the IPL 2010 Final. What are your favourites from the IPL? #WhistlePodu #AnbuDenLions 🦁💛',
#   'publishedAt': '2020-04-13T07:39:53Z',
#   'viewCount': '60843',
#   'likeCount': '3771',
#   'commentCount': '64'},
#  {'video_id': '8Tk-582bBik',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Gracia named Rio; CSK for Life! - Suresh Raina',
#   'description': "Chinna Thala Suresh Raina opens up about his exotic names for the children and who's the boss of the house.",
#   'publishedAt': '2020-04-12T14:08:45Z',
#   'viewCount': '60026',
#   'likeCount': '4499',
#   'commentCount': '53'},
#  {'video_id': 'A6m1GCuKJ1w',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Suresh Raina cooking during lockdown',
#   'description': '#AnbuDenLions #WhistlePodu #Yellove',
#   'publishedAt': '2020-04-12T09:46:51Z',
#   'viewCount': '60444',
#   'likeCount': '4029',
#   'commentCount': '50'},
#  {'video_id': 'CSJL28AsN4I',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Chennai Super Cubs Easter Egg Hunt',
#   'description': "Throwback to the cutest egg hunt you'll ever see! Wishing you all a super #HappyEaster! May we all rise with hope in these difficult times. 🦁💛",
#   'publishedAt': '2020-04-12T06:22:38Z',
#   'viewCount': '57239',
#   'likeCount': '2954',
#   'commentCount': '53'},
#  {'video_id': 'salxHYPRHCg',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Episode #1 - AnbuDen Lions featuring Deepak Chahar',
#   'description': "Cherry gave #AnbuDenLions the sweetest of starts! Here's the full episode. #WhistlePodu #PUBG #Dhoni #Yellove #Pets 🦁💛",
#   'publishedAt': '2020-04-11T13:07:09Z',
#   'viewCount': '46796',
#   'likeCount': '2226',
#   'commentCount': '72'},
#  {'video_id': '82Lhu1JNNcQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Albie Morkel finally opens up about those famous 28 off 7',
#   'description': '#AnbuDenLions #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-10T15:28:54Z',
#   'viewCount': '93804',
#   'likeCount': '4529',
#   'commentCount': '180'},
#  {'video_id': '-SCUOlKMauk',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Faf du Plessis super work out during the lockdown',
#   'description': 'Faf and Furious! #WhistlePodu #Yellove',
#   'publishedAt': '2020-04-10T09:09:54Z',
#   'viewCount': '31398',
#   'likeCount': '1515',
#   'commentCount': '60'},
#  {'video_id': 'mEYJbKjh68I',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Deepak Chahar and the gym competition in the Chahar Family',
#   'description': '#AnbuDenLions #WhistlePodu',
#   'publishedAt': '2020-04-09T05:41:48Z',
#   'viewCount': '18044',
#   'likeCount': '986',
#   'commentCount': '32'},
#  {'video_id': 'zhpmTXKqoIQ',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Curd Rice, Pickle and Dal Fry are my favourite Chennai food! - Matthew Hayden',
#   'description': 'Curd rice & pickle, catch off Pollard in IPL 2010 Final and a #COVID2019 message to all the Indian fans, Matthew Hayden says it all! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-08T12:38:40Z',
#   'viewCount': '13884',
#   'likeCount': '843',
#   'commentCount': '45'},
#  {'video_id': 'F4MchI-9KTs',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"When I was in my mother\'s womb, I was in Chennai." - Deepak Chahar',
#   'description': "Deepak's mom learnt to make Idly and Dosa there and he has been having it since I was one! #AnbuDenLions #WhistlePodu 🦁💛",
#   'publishedAt': '2020-04-08T08:19:30Z',
#   'viewCount': '43449',
#   'likeCount': '2427',
#   'commentCount': '53'},
#  {'video_id': 'JEuMT1FRGz8',
#   'channelTitle': 'Chennai Super Kings',
#   'title': '"Denzo understands everything" - Deepak Chahar on his pet Labrador',
#   'description': 'A cute little bowwboww intervention happened during the #AnbuDenLions LIVE with namma #Cherry! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-07T16:04:31Z',
#   'viewCount': '29849',
#   'likeCount': '1666',
#   'commentCount': '36'},
#  {'video_id': 'YiCNOtXDznc',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Suresh Raina training with Gracia and kids',
#   'description': '#Plank #Training #IndoorGym #StayHomeStaySafe',
#   'publishedAt': '2020-04-07T10:42:14Z',
#   'viewCount': '19229',
#   'likeCount': '1185',
#   'commentCount': '48'},
#  {'video_id': 'uCKkqJjbBq4',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Mahi bhai has moved on from PUBG to COD now - Deepak Chahar',
#   'description': 'In the inaugural episode of #AnbuDenLions, namma Cherry got talking about playing PUBG with #Thala Dhoni and why guys love to learn the guitar! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-07T05:20:19Z',
#   'viewCount': '297075',
#   'likeCount': '14534',
#   'commentCount': '305'},
#  {'video_id': 'RmuG57cW_4o',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'Suresh Raina playing cricket at home during lockdown',
#   'description': 'Incredible tit-for-tat gully cricket scenes at the #ChinnaThala household! #Gracia',
#   'publishedAt': '2020-04-06T14:14:12Z',
#   'viewCount': '1155049',
#   'likeCount': '40061',
#   'commentCount': '167'},
#  {'video_id': 'KPf7U1Qp014',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'CSK Practice Match at Chepauk 2020',
#   'description': 'In an ideal world, this is how the Super Kings would have worked from home. Scenes from a few weeks ago, when the Lions worked from #AnbuDen, anbuden! #WhistlePodu 🦁💛',
#   'publishedAt': '2020-04-05T12:36:27Z',
#   'viewCount': '2160159',
#   'likeCount': '48746',
#   'commentCount': '763'},
#  {'video_id': 'fDhde1idz-I',
#   'channelTitle': 'Chennai Super Kings',
#   'title': "Mitchell Santner's mind-blowing Golf Trick Shots",
#   'description': "When #SantaClaws gets bored in the house, he creates magic...magic that can't be 'putt' into words! #Golf #QuarantineLife 🦁💛",
#   'publishedAt': '2020-04-04T15:45:57Z',
#   'viewCount': '80216',
#   'likeCount': '7436',
#   'commentCount': '84'},
#  {'video_id': 'XHD8J42UEYA',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'CSK Fans win epic Trivia Battle against MI Fans',
#   'description': "Missing the last over finishes? Here's a superb one, one with a Super Over! In an epic #MIvCSK trivia battle, a typical finish for namma #SuperFans! Catch the all-new #CricketConnected at 7 PM and 9 PM today on Star Sports 1/1HD/2/2HD for more on the rivalry! #WhistlePodu 🦁💛",
#   'publishedAt': '2020-04-04T12:14:10Z',
#   'viewCount': '12611',
#   'likeCount': '1081',
#   'commentCount': '47'},
#  {'video_id': 'Wr7fjfdkSBo',
#   'channelTitle': 'Chennai Super Kings',
#   'title': 'A musical piece on Dhoni and CSK by Super Fan Sarvajit',
#   'description': 'Artforms are taking super shapes during these tough times. #SuperFan Sarvajit has this brilliant little piece on #Thala Dhoni and team. Send us all your art/artform/anything yellove on Twitter with the hashtag #YelloveFromHome and get featured! 🦁💛',
#   'publishedAt': '2020-04-04T04:58:00Z',
#   'viewCount': '28957',
#   'likeCount': '2691',
#   'commentCount': '44'},
#  ...]

# %%
videos_df = pd.DataFrame(videos)
videos_df
# Out:
#          video_id         channelTitle  \
# 0     f1gnaV4sWYo  Chennai Super Kings
# 1     85adJ60bQqk  Chennai Super Kings
# 2     zdZmopaH8vA  Chennai Super Kings
# 3     r88fWNdYmPc  Chennai Super Kings
# 4     o29L2ysDYeY  Chennai Super Kings
# ...           ...                  ...
# 1087  7jLIsp6nxc8  Chennai Super Kings
# 1088  gExoAZDWy5I  Chennai Super Kings
# 1089  tOC2sRyr1Uw  Chennai Super Kings
# 1090  l3HyqIgrM9I  Chennai Super Kings
# 1091  cZNbDuibM5A  Chennai Super Kings
#
#                                                   title  \
# 0     That sounds Mo like a perfect team 😎Pick yours...
# 1     Thala's birthday gift 🎥💛#CelebratingThala #Whi...
# 2     The THALA Emotion - MS Dhoni Birthday Special ...
# 3     Test Cricket’s an art and Bens got those maste...
# 4     Does your All time XI match with that of Conwa...
# ...                                                 ...
# 1087                        CSK Whistle Podu - 2011 New
# 1088                            CSK Whistle Podu - 2010
# 1089  CSK Whistle Podu fan video ( 60 sec TELEVISION...
# 1090                  Whistle Podu 4 Super Kings (full)
# 1091                                       Whistle Podu
#
#                                             description           publishedAt  \
# 0                                                        2023-07-21T09:10:58Z
# 1                                                        2023-07-08T11:26:55Z
# 2     It's his day, our day! Join in as we celebrate...  2023-07-07T09:08:20Z
# 3                                                        2023-07-04T11:17:36Z
# 4                                                        2023-07-03T10:46:32Z
# ...                                                 ...                   ...
# 1087  New and updated version! If you wanna you be p...  2011-04-15T10:59:01Z
# 1088  New and updated version! Catch DHONI, BALAJI, ...  2010-03-18T04:36:27Z
# 1089  Thanks to Popular demand and the overwhelming ...  2009-05-22T17:47:39Z
# 1090            Whistle Podu 4 Super Kings (full video)  2009-04-28T09:53:33Z
# 1091                                    Fan Video Promo  2009-04-17T13:33:17Z
#
#      viewCount likeCount commentCount
# 0        15105      1885           22
# 1       153634     28322          309
# 2       200780     21810         1160
# 3        41837      5772           28
# 4        42806      6491           78
# ...        ...       ...          ...
# 1087    155380      3422          105
# 1088   2346364     70811         2749
# 1089     39871       713           41
# 1090    510192      6391          267
# 1091    136173      8249          530
#
# [1092 rows x 8 columns]

# %% [markdown]
# #Data Transformation
# ![637f242f02ba099898c68400_Data-Transform.jpg](data:image/jpeg;base64,...)

# %%
#Channel_subscribers to int
ChannelDetails["Channel_subscribers"] = ChannelDetails["Channel_subscribers"].astype(int)
#Channel_view_Count to int
ChannelDetails["Channel_view_Count"] = ChannelDetails["Channel_view_Count"].astype(int)
#Channel_Published_Date to datetime
ChannelDetails["Channel_Published_Date"] = pd.to_datetime(ChannelDetails["Channel_Published_Date"])
#Channel_video_Count to int
ChannelDetails["channel_Video_Count"] = ChannelDetails["channel_Video_Count"].astype(int)
ChannelDetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Channel_id              1 non-null      object
#  1   Channel_name            1 non-null      object
#  2   Channel_description     1 non-null      object
#  3   Channel_subscribers     1 non-null      int64
#  4   Channel_view_Count      1 non-null      int64
#  5   channel_Video_Count     1 non-null      int64
#  6   Channel_Published_Date  1 non-null      datetime64[ns, UTC]
#  7   Playlist_id             1 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(3), object(4)
# memory usage: 72.0+ bytes

# %%
import numpy as np

# %%
videos_df['commentCount'].fillna(0, inplace=True)
videos_df['likeCount'].fillna(0, inplace=True)
videos_df['viewCount'].fillna(0, inplace=True)

# %%
#publish date is in string format to convert to datetime
videos_df['publishedAt'] = pd.to_datetime(videos_df['publishedAt'])


#view count is in string format to convert to int
videos_df['viewCount'] = videos_df['viewCount'].astype(int)

#like count is in string format to convert to int
videos_df['likeCount'] = videos_df['likeCount'].astype(int)

#comment count is in string format to convert to int
videos_df['commentCount'] = videos_df['commentCount'].astype(int)
videos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      1092 non-null   object
#  1   channelTitle  1092 non-null   object
#  2   title         1092 non-null   object
#  3   description   1092 non-null   object
#  4   publishedAt   1092 non-null   datetime64[ns, UTC]
#  5   viewCount     1092 non-null   int64
#  6   likeCount     1092 non-null   int64
#  7   commentCount  1092 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(3), object(4)
# memory usage: 68.4+ KB

# %%
# video published date to year , month
videos_df['publishedAt'] = pd.to_datetime(videos_df['publishedAt'])
videos_df['Published_Year'] = videos_df['publishedAt'].dt.year
videos_df['Published_Month'] = videos_df['publishedAt'].dt.month.map({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})

# %%
videos_df
# Out:
#          video_id         channelTitle  \
# 0     f1gnaV4sWYo  Chennai Super Kings
# 1     85adJ60bQqk  Chennai Super Kings
# 2     zdZmopaH8vA  Chennai Super Kings
# 3     r88fWNdYmPc  Chennai Super Kings
# 4     o29L2ysDYeY  Chennai Super Kings
# ...           ...                  ...
# 1087  7jLIsp6nxc8  Chennai Super Kings
# 1088  gExoAZDWy5I  Chennai Super Kings
# 1089  tOC2sRyr1Uw  Chennai Super Kings
# 1090  l3HyqIgrM9I  Chennai Super Kings
# 1091  cZNbDuibM5A  Chennai Super Kings
#
#                                                   title  \
# 0     That sounds Mo like a perfect team 😎Pick yours...
# 1     Thala's birthday gift 🎥💛#CelebratingThala #Whi...
# 2     The THALA Emotion - MS Dhoni Birthday Special ...
# 3     Test Cricket’s an art and Bens got those maste...
# 4     Does your All time XI match with that of Conwa...
# ...                                                 ...
# 1087                        CSK Whistle Podu - 2011 New
# 1088                            CSK Whistle Podu - 2010
# 1089  CSK Whistle Podu fan video ( 60 sec TELEVISION...
# 1090                  Whistle Podu 4 Super Kings (full)
# 1091                                       Whistle Podu
#
#                                             description  \
# 0
# 1
# 2     It's his day, our day! Join in as we celebrate...
# 3
# 4
# ...                                                 ...
# 1087  New and updated version! If you wanna you be p...
# 1088  New and updated version! Catch DHONI, BALAJI, ...
# 1089  Thanks to Popular demand and the overwhelming ...
# 1090            Whistle Podu 4 Super Kings (full video)
# 1091                                    Fan Video Promo
#
#                    publishedAt  viewCount  likeCount  commentCount  \
# 0    2023-07-21 09:10:58+00:00      15105       1885            22
# 1    2023-07-08 11:26:55+00:00     153634      28322           309
# 2    2023-07-07 09:08:20+00:00     200780      21810          1160
# 3    2023-07-04 11:17:36+00:00      41837       5772            28
# 4    2023-07-03 10:46:32+00:00      42806       6491            78
# ...                        ...        ...        ...           ...
# 1087 2011-04-15 10:59:01+00:00     155380       3422           105
# 1088 2010-03-18 04:36:27+00:00    2346364      70811          2749
# 1089 2009-05-22 17:47:39+00:00      39871        713            41
# 1090 2009-04-28 09:53:33+00:00     510192       6391           267
# 1091 2009-04-17 13:33:17+00:00     136173       8249           530
#
#       Published_Year Published_Month
# 0               2023             Jul
# 1               2023             Jul
# 2               2023             Jul
# 3               2023             Jul
# 4               2023             Jul
# ...              ...             ...
# 1087            2011             Apr
# 1088            2010             Mar
# 1089            2009             May
# 1090            2009             Apr
# 1091            2009             Apr
#
# [1092 rows x 10 columns]

# %% [markdown]
# #**Load data into database**
#
# ![SQLite370.svg.png](data:image/png;base64,...)

# %%
import sqlite3
con = sqlite3.connect('youtube.db')

# %%
videos_df.to_sql('videos', con, if_exists='append')
ChannelDetails.to_sql('ChannelDetails', con, if_exists='append')
# Out:
# 1

# %% [markdown]
# # **Read from sqlite3**

# %%
videos_df = pd.read_sql('select * from videos', con, index_col='index')
ChannelDetails = pd.read_sql('select * from ChannelDetails', con, index_col='index')

# %%
ChannelDetails
# Out:
#                      Channel_id         Channel_name  \
# index
# 0      UC2J_VKrAzOEJuQvFFtj3KUw  Chennai Super Kings
#
#                                      Channel_description  Channel_subscribers  \
# index
# 0      The Official YouTube Channel of the Chennai Su...              3140000
#
#        Channel_view_Count  channel_Video_Count     Channel_Published_Date  \
# index
# 0               619226573                 1092  2009-04-17 13:00:30+00:00
#
#                     Playlist_id
# index
# 0      UU2J_VKrAzOEJuQvFFtj3KUw

# %%
videos_df
# Out:
#           video_id         channelTitle  \
# index
# 0      f1gnaV4sWYo  Chennai Super Kings
# 1      85adJ60bQqk  Chennai Super Kings
# 2      zdZmopaH8vA  Chennai Super Kings
# 3      r88fWNdYmPc  Chennai Super Kings
# 4      o29L2ysDYeY  Chennai Super Kings
# ...            ...                  ...
# 1087   7jLIsp6nxc8  Chennai Super Kings
# 1088   gExoAZDWy5I  Chennai Super Kings
# 1089   tOC2sRyr1Uw  Chennai Super Kings
# 1090   l3HyqIgrM9I  Chennai Super Kings
# 1091   cZNbDuibM5A  Chennai Super Kings
#
#                                                    title  \
# index
# 0      That sounds Mo like a perfect team 😎Pick yours...
# 1      Thala's birthday gift 🎥💛#CelebratingThala #Whi...
# 2      The THALA Emotion - MS Dhoni Birthday Special ...
# 3      Test Cricket’s an art and Bens got those maste...
# 4      Does your All time XI match with that of Conwa...
# ...                                                  ...
# 1087                         CSK Whistle Podu - 2011 New
# 1088                             CSK Whistle Podu - 2010
# 1089   CSK Whistle Podu fan video ( 60 sec TELEVISION...
# 1090                   Whistle Podu 4 Super Kings (full)
# 1091                                        Whistle Podu
#
#                                              description  \
# index
# 0
# 1
# 2      It's his day, our day! Join in as we celebrate...
# 3
# 4
# ...                                                  ...
# 1087   New and updated version! If you wanna you be p...
# 1088   New and updated version! Catch DHONI, BALAJI, ...
# 1089   Thanks to Popular demand and the overwhelming ...
# 1090             Whistle Podu 4 Super Kings (full video)
# 1091                                     Fan Video Promo
#
#                      publishedAt  viewCount  likeCount  commentCount  \
# index
# 0      2023-07-21 09:10:58+00:00      15105       1885            22
# 1      2023-07-08 11:26:55+00:00     153634      28322           309
# 2      2023-07-07 09:08:20+00:00     200780      21810          1160
# 3      2023-07-04 11:17:36+00:00      41837       5772            28
# 4      2023-07-03 10:46:32+00:00      42806       6491            78
# ...                          ...        ...        ...           ...
# 1087   2011-04-15 10:59:01+00:00     155380       3422           105
# 1088   2010-03-18 04:36:27+00:00    2346364      70811          2749
# 1089   2009-05-22 17:47:39+00:00      39871        713            41
# 1090   2009-04-28 09:53:33+00:00     510192       6391           267
# 1091   2009-04-17 13:33:17+00:00     136173       8249           530
#
#        Published_Year Published_Month
# index
# 0                2023             Jul
# 1                2023             Jul
# 2                2023             Jul
# 3                2023             Jul
# 4                2023             Jul
# ...               ...             ...
# 1087             2011             Apr
# 1088             2010             Mar
# 1089             2009             May
# 1090             2009             Apr
# 1091             2009             Apr
#
# [1092 rows x 10 columns]

# %% [markdown]
# # **Data Analysis**
#
# ![What-is-Data-Analysis.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Exploratory Data Analysis**

# %%
videos_df.describe()
# Out:
#           viewCount     likeCount  commentCount  Published_Year
# count  1.092000e+03  1.092000e+03   1092.000000     1092.000000
# mean   5.670700e+05  2.858567e+04    605.466117     2021.148352
# std    2.140327e+06  6.744444e+04    999.958791        1.645472
# min    2.481000e+03  6.600000e+01      0.000000     2009.000000
# 25%    6.861850e+04  5.360250e+03    120.000000     2020.000000
# 50%    1.592540e+05  1.273750e+04    305.000000     2021.000000
# 75%    3.846170e+05  2.834600e+04    724.750000     2022.000000
# max    3.941736e+07  1.399788e+06  14841.000000     2023.000000

# %% [markdown]
# #Descriptive statistics
# #Infrential statistics
# #Predective statistics
# #Prescriptive statistics

# %% [markdown]
# #**Univariate Analysis**
#
#
#
# 1.   Histogram
# 2.   Boxplot
# 3.   Distribution plot
# 3.   Pie plot
# 4.   bar plot

# %%
videos_df
# Out:
#           video_id         channelTitle  \
# index
# 0      f1gnaV4sWYo  Chennai Super Kings
# 1      85adJ60bQqk  Chennai Super Kings
# 2      zdZmopaH8vA  Chennai Super Kings
# 3      r88fWNdYmPc  Chennai Super Kings
# 4      o29L2ysDYeY  Chennai Super Kings
# ...            ...                  ...
# 1087   7jLIsp6nxc8  Chennai Super Kings
# 1088   gExoAZDWy5I  Chennai Super Kings
# 1089   tOC2sRyr1Uw  Chennai Super Kings
# 1090   l3HyqIgrM9I  Chennai Super Kings
# 1091   cZNbDuibM5A  Chennai Super Kings
#
#                                                    title  \
# index
# 0      That sounds Mo like a perfect team 😎Pick yours...
# 1      Thala's birthday gift 🎥💛#CelebratingThala #Whi...
# 2      The THALA Emotion - MS Dhoni Birthday Special ...
# 3      Test Cricket’s an art and Bens got those maste...
# 4      Does your All time XI match with that of Conwa...
# ...                                                  ...
# 1087                         CSK Whistle Podu - 2011 New
# 1088                             CSK Whistle Podu - 2010
# 1089   CSK Whistle Podu fan video ( 60 sec TELEVISION...
# 1090                   Whistle Podu 4 Super Kings (full)
# 1091                                        Whistle Podu
#
#                                              description  \
# index
# 0
# 1
# 2      It's his day, our day! Join in as we celebrate...
# 3
# 4
# ...                                                  ...
# 1087   New and updated version! If you wanna you be p...
# 1088   New and updated version! Catch DHONI, BALAJI, ...
# 1089   Thanks to Popular demand and the overwhelming ...
# 1090             Whistle Podu 4 Super Kings (full video)
# 1091                                     Fan Video Promo
#
#                      publishedAt  viewCount  likeCount  commentCount  \
# index
# 0      2023-07-21 09:10:58+00:00      15105       1885            22
# 1      2023-07-08 11:26:55+00:00     153634      28322           309
# 2      2023-07-07 09:08:20+00:00     200780      21810          1160
# 3      2023-07-04 11:17:36+00:00      41837       5772            28
# 4      2023-07-03 10:46:32+00:00      42806       6491            78
# ...                          ...        ...        ...           ...
# 1087   2011-04-15 10:59:01+00:00     155380       3422           105
# 1088   2010-03-18 04:36:27+00:00    2346364      70811          2749
# 1089   2009-05-22 17:47:39+00:00      39871        713            41
# 1090   2009-04-28 09:53:33+00:00     510192       6391           267
# 1091   2009-04-17 13:33:17+00:00     136173       8249           530
#
#        Published_Year Published_Month
# index
# 0                2023             Jul
# 1                2023             Jul
# 2                2023             Jul
# 3                2023             Jul
# 4                2023             Jul
# ...               ...             ...
# 1087             2011             Apr
# 1088             2010             Mar
# 1089             2009             May
# 1090             2009             Apr
# 1091             2009             Apr
#
# [1092 rows x 10 columns]

# %%
videos_df['channelTitle'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.2)

# %%
import plotly.express as px

# %%
ch=videos_df['channelTitle'].value_counts()

fig=px.pie(ch, values=ch, names=ch.index, title='Channel name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6b3f5ed5-77b7-496c-b26d-64b88851e7a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b3f5ed5-77b7-496c-b26d-64b88851e7a1")) {                    Plotly.newPlot(                        "6b3f5ed5-77b7-496c-b26d-64b88851e7a1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Chennai Super Kings"],"legendgroup":"","name":"","showlegend":true,"values":[1092],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity" ...

# %%
videos_df['viewCount'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
px.histogram(videos_df, x='viewCount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="441b215a-a957-4b14-863f-adcee66448cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("441b215a-a957-4b14-863f-adcee66448cb")) {                    Plotly.newPlot(                        "441b215a-a957-4b14-863f-adcee66448cb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"viewCount=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[15105,153634,200780,41837,42806,225054,148027,72925,29644,20709,28856,156056,424298,1521020,1258113,179685,88408,131193,84930,573551,107704,39634,61496,442529,12531619,57647,66184,99277,305081,96935,79063,308470,398880,205067,178362,68718,65759,34835,37905,317809,47932,121950,21716,67009,76753,52864,47138,21206,715968,380239,42730,61632,347510,335640,107418,553329,84477,38049,30185,58101,408739,206643,47922,97963,5820739,175450,95915,53141,68297,1585558,118944,27994,111051,315488,2450809,29528,172627,3655056,64016,54039,45531,23157,194745,32544,35109,206204,14850,31012,216095,6296247,36525,42342,382815,252075,77887,202114,192483,48783,248150,68713,62613,255129,201470,141662,114367,31104,98748,96743,41519,107940,130426,107508,809767,287872,161500,446431,89242,36261,414827,24575,85381,21842,57890,76400,58721,189466,134000,401027,91597,62263,127475,227652,620271,315724,225198,426849,2004873,50650,150971,126693,174401,77919,103230,852677,39303,66661,812413,159254,529766,338623,186542,316278,83513,234086,1049217,232078,12397193,136588,913722,209460,272691,609073,2388626,246238,266778,169690,412002,133567,268490,409981,492219,863880,84168,381968,193877,278855,418875,543159,339437,459007,403994,2114589,181178,415253,181490,940305,237615,549250,528427,1574872,270473,769275,485228,236632,214512,374422,144638,113392,79175,546890,74851,125938,80076,62317,63160,416578,124273,191594,37162,113981,84466,107643,60619,782807,87422,1705543,48081,103171,80432,52143,26286,63728,177281,246217,35656,3519472,203666,86687,175681,65642,124374,275591,67135,129727,305119,101098,147573,63680,185925,195333,28184,40766,141564,38125,29928,55287,30411,53960,38326,26144,70203,47883,81076,23831,73775,85851,56733,203289,35453,611084,56827,44541,43738,56720,273632,23597,60093,17634,41890,50589,138448,164984,377203,79449,52144,71822,45075,29240,35801,226076,83526,77162,546213,32823,198926,21184,24075,92884,44189,995767,273823,35456,13958,250874,298003,9937,42251,44727,56667,17817,52199,58286,1323833,61654,229445,63470,205364,15511,25148,11783,85638,82376,14228,17964,17209,158400,91708,13979,22905,20640,15750,20921,30602,38193,64125,157536,118900,37898,43858,10010,19613,38808,60319,183709,23225,160361,98070,20283,70254,112845,54102,29721,144147,54122,79169,127282,90156,40799,57363,125744,109512,98825,297155,42244,87274,49531,134732,23420,39298,135805,152610,90450,159254,159129,160811,60427,71498,85251,46376,121299,322681,41886,95657,117165,68654,70819,100783,207476,193362,79129,148611,185328,5329840,129393,56275,170108,399437,373574,275352,254714,532701,104627,215469,182079,204647,762293,99324,64918,60573,58366,91279,83787,498580,229138,67687,123624,78371,56339,212705,102546,417653,145821,112685,60364,321252,263445,209852,244725,364877,414396,175933,272152,234596,841176,328690,341307,320877,552435,1356776,526059,346243,656887,382253,381028,323640,756073,381727,333750,323781,847538,461292,470652,479954,367771,468247,992812,704246,853558,1363799,2206719,142239,130716,188266,233476,170125,192974,355588,711398,131615,237725,206984,272612,852919,151314,308971,209024,71316,127203,263473,155838,235382,75716,116087,2177211,59714,133218,82070,32159,711182,135008,141148,304244,84419,61801,221230,20396 ...

# %%
videos_df['Published_Year'].value_counts().plot(kind='bar')
py=videos_df['Published_Year'].value_counts()

# %%
py=videos_df.groupby('Published_Year')['Published_Year'].count()
py
# Out:
# Published_Year
# 2009      3
# 2010      1
# 2011      2
# 2012      2
# 2013      1
# 2014      4
# 2015      3
# 2018     10
# 2019     42
# 2020    289
# 2021    253
# 2022    260
# 2023    222
# Name: Published_Year, dtype: int64

# %%
px.pie(py, values=py, names=py.index, title='Published Year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="17d4c149-7891-405a-953b-d35a828655f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17d4c149-7891-405a-953b-d35a828655f3")) {                    Plotly.newPlot(                        "17d4c149-7891-405a-953b-d35a828655f3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":[2009,2010,2011,2012,2013,2014,2015,2018,2019,2020,2021,2022,2023],"legendgroup":"","name":"","showlegend":true,"values":[3,1,2,2,1,4,3,10,42,289,253,260,222],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"h ...

# %%
videos_df['Published_Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
px.histogram(videos_df, x='likeCount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0581e7fa-c4d1-40a7-bea6-ef626fdc704f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0581e7fa-c4d1-40a7-bea6-ef626fdc704f")) {                    Plotly.newPlot(                        "0581e7fa-c4d1-40a7-bea6-ef626fdc704f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"likeCount=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1885,28322,21810,5772,6491,13327,18404,10605,1736,1411,2155,19306,63334,72265,66323,7449,4840,7157,4774,17418,4692,2820,3132,21284,503444,3417,3660,6677,17405,6382,4360,27848,28234,15935,9733,3918,4704,2248,3292,18102,2908,2932,1678,3298,4972,2956,2882,1664,64005,21059,2649,4616,11923,39250,10469,13712,4720,2677,2185,4092,14429,20607,3348,8315,231725,15027,6791,3522,4329,34588,9165,2377,6590,18737,143617,2501,13192,156898,4924,3563,3439,2141,12428,2746,2421,21679,1591,2529,8749,356360,3306,2795,37242,22843,5290,21361,11220,4851,30345,3848,4251,27797,15189,8732,5454,2642,6359,4700,3494,5933,6293,5072,56681,11196,16125,37312,5511,2684,38853,2091,6182,1887,3845,5350,4414,13989,7153,46958,6285,4752,18993,17286,31138,32363,20552,41472,130065,3976,8482,8555,23461,5890,6774,58910,2351,5399,52492,12158,33636,40302,12475,33026,5041,20232,65166,19546,468235,8170,50170,11160,27100,89144,168424,12302,14062,10523,33983,8079,34524,48750,26871,86935,5603,52867,11538,36549,54784,66266,37928,33255,16718,117457,11213,44367,17460,81301,26380,61037,70046,65266,16306,90665,56423,15026,28176,24450,18914,14324,8675,65683,5004,15420,10362,6522,3949,42291,10537,4767,3896,16707,11339,5856,6577,66812,10771,104910,1792,4818,8697,4101,1307,3759,23699,31860,2811,207417,31526,11859,13456,10830,10509,37317,6785,11323,49915,8701,17227,6618,10133,28907,4951,3555,7680,3362,2772,4264,6016,6828,4767,2154,8530,6317,12318,3057,9585,12641,7919,17799,8749,62225,6444,2719,8000,5715,47048,4060,10011,1612,3695,6511,11966,26301,27415,6130,4021,4785,4852,1595,2949,15924,6948,13042,9941,2249,21600,2022,2617,14197,3654,81971,36737,3624,1336,17069,29220,1149,5193,5521,7995,1790,7304,11331,76081,11452,33516,8715,28418,1371,2226,1369,11038,3441,1268,1914,2141,13164,9490,1914,2557,1942,1699,2874,2615,3299,7977,12812,9675,4434,5289,1359,1948,2626,4629,9908,2536,10563,7285,1801,5734,7850,5215,3073,10313,4261,7951,11754,7555,3701,5358,10538,9972,7895,15189,4538,4807,4081,11077,2386,3434,12726,10584,8163,14796,11793,13792,6380,3932,6151,4072,8408,16227,3663,6906,10652,7034,5667,8827,14433,15993,6774,11341,13025,117882,7147,4518,15641,24355,25353,15219,16154,27994,8690,16769,16044,15997,43827,7127,5533,4516,5423,8466,8022,26250,17404,6616,10775,6809,4838,17746,10166,34547,18291,9340,7535,27022,24670,15438,20542,30572,32706,13308,23153,29326,78563,25515,28562,28787,54378,107015,40772,34019,71292,32574,31849,20228,58180,29530,25414,20212,71532,30401,36974,34996,31436,49301,62065,47671,50229,38942,130200,11346,11013,17190,19041,16584,23971,40965,45323,7740,22195,17331,20800,97217,11974,28504,27506,5169,13886,17251,14226,16251,7500,9116,39911,5503,11078,10849,3841,70676,15222,15109,20950,7175,6622,4439,139513,4684,22658,21771,41362,83552,19392,126882,77377,14494,24924,19877,6950,7186,20934,12287,426996,73438,195906,44130,150895,35364,54452,11293,19406,63326,19822,17359,8486,44635,11885,38819,8333,5538,6479,6785,504380,5044,5785,256684,22500,7833,6788,45998,11695,9208,29456,5072,11468,44527,7864,4550,12482,13468,39621,18641,8623,11524,20487,19813,13462,9991,25891,42506,10635,13506,14312,12970,10028,45664,17418,69385,19565,28541,14546,16553,25851,13250,23047,47741,33351,10719,19008,20635,37650,29612,12872,18800,8528 ...

# %% [markdown]
# #**Bivariate Analysis**
#
#
#
# 1.   Sactter plot - (Numerical vs Numerical)
# 2.   Bar plot -(Categorial vs Numerical)
# 3.   line plot - (Categorial vs Numerical)/ TimeSeries
# 4.   Stacked Bar - (Categorical vs Categorical)

# %%
#View count vs Like count

px.scatter(videos_df, x='viewCount', y='likeCount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="19375a24-0632-4d19-87c0-bd1e6512fb00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19375a24-0632-4d19-87c0-bd1e6512fb00")) {                    Plotly.newPlot(                        "19375a24-0632-4d19-87c0-bd1e6512fb00",                        [{"hovertemplate":"viewCount=%{x}<br>likeCount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[15105,153634,200780,41837,42806,225054,148027,72925,29644,20709,28856,156056,424298,1521020,1258113,179685,88408,131193,84930,573551,107704,39634,61496,442529,12531619,57647,66184,99277,305081,96935,79063,308470,398880,205067,178362,68718,65759,34835,37905,317809,47932,121950,21716,67009,76753,52864,47138,21206,715968,380239,42730,61632,347510,335640,107418,553329,84477,38049,30185,58101,408739,206643,47922,97963,5820739,175450,95915,53141,68297,1585558,118944,27994,111051,315488,2450809,29528,172627,3655056,64016,54039,45531,23157,194745,32544,35109,206204,14850,31012,216095,6296247,36525,42342,382815,252075,77887,202114,192483,48783,248150,68713,62613,255129,201470,141662,114367,31104,98748,96743,41519,107940,130426,107508,809767,287872,161500,446431,89242,36261,414827,24575,85381,21842,57890,76400,58721,189466,134000,401027,91597,62263,127475,227652,620271,315724,225198,426849,2004873,50650,150971,126693,174401,77919,103230,852677,39303,66661,812413,159254,529766,338623,186542,316278,83513,234086,1049217,232078,12397193,136588,913722,209460,272691,609073,2388626,246238,266778,169690,412002,133567,268490,409981,492219,863880,84168,381968,193877,278855,418875,543159,339437,459007,403994,2114589,181178,415253,181490,940305,237615,549250,528427,1574872,270473,769275,485228,236632,214512,374422,144638,113392,79175,546890,74851,125938,80076,62317,63160,416578,124273,191594,37162,113981,84466,107643,60619,782807,87422,1705543,48081,103171,80432,52143,26286,63728,177281,246217,35656,3519472,203666,86687,175681,65642,124374,275591,67135,129727,305119,101098,147573,63680,185925,195333,28184,40766,141564,38125,29928,55287,30411,53960,38326,26144,70203,47883,81076,23831,73775,85851,56733,203289,35453,611084,56827,44541,43738,56720,273632,23597,60093,17634,41890,50589,138448,164984,377203,79449,52144,71822,45075,29240,35801,226076,83526,77162,546213,32823,198926,21184,24075,92884,44189,995767,273823,35456,13958,250874,298003,9937,42251,44727,56667,17817,52199,58286,1323833,61654,229445,63470,205364,15511,25148,11783,85638,82376,14228,17964,17209,158400,91708,13979,22905,20640,15750,20921,30602,38193,64125,157536,118900,37898,43858,10010,19613,38808,60319,183709,23225,160361,98070,20283,70254,112845,54102,29721,144147,54122,79169,127282,90156,40799,57363,125744,109512,98825,297155,42244,87274,49531,134732,23420,39298,135805,152610,90450,159254,159129,160811,60427,71498,85251,46376,121299,322681,41886,95657,117165,68654,70819,100783,207476,193362,79129,148611,185328,5329840,129393,56275,170108,399437,373574,275352,254714,532701,104627,215469,182079,204647,762293,99324,64918,60573,58366,91279,83787,498580,229138,67687,123624,78371,56339,212705,102546,417653,145821,112685,60364,321252,263445,209852,244725,364877,414396,175933,272152,234596,841176,328690,341307,320877,552435,1356776,526059,346243,656887,382253,381028,323640,756073,381727,333750,323781,847538,461292,470652,479954,367771,468247,992812,704246,853558,1363799,2206719,142239,130716,188266,233476,170125,192974,355588,711398,131615,237725,206984,272612,852919,151314,308971,209024,71316,127203,263473,155838,235382,75716,116087,2177211,59714,133218,82070,32159,711182,135008,141148,304244,84419,61801,221230,2039687,49822,183318,182259,612554,1225201,130519,2246044,93156 ...

# %%
#view count vs Comment count
px.scatter(videos_df, x='viewCount', y='commentCount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="16e6e5ec-4ea1-459f-a058-556afbf4dd47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16e6e5ec-4ea1-459f-a058-556afbf4dd47")) {                    Plotly.newPlot(                        "16e6e5ec-4ea1-459f-a058-556afbf4dd47",                        [{"hovertemplate":"viewCount=%{x}<br>commentCount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[15105,153634,200780,41837,42806,225054,148027,72925,29644,20709,28856,156056,424298,1521020,1258113,179685,88408,131193,84930,573551,107704,39634,61496,442529,12531619,57647,66184,99277,305081,96935,79063,308470,398880,205067,178362,68718,65759,34835,37905,317809,47932,121950,21716,67009,76753,52864,47138,21206,715968,380239,42730,61632,347510,335640,107418,553329,84477,38049,30185,58101,408739,206643,47922,97963,5820739,175450,95915,53141,68297,1585558,118944,27994,111051,315488,2450809,29528,172627,3655056,64016,54039,45531,23157,194745,32544,35109,206204,14850,31012,216095,6296247,36525,42342,382815,252075,77887,202114,192483,48783,248150,68713,62613,255129,201470,141662,114367,31104,98748,96743,41519,107940,130426,107508,809767,287872,161500,446431,89242,36261,414827,24575,85381,21842,57890,76400,58721,189466,134000,401027,91597,62263,127475,227652,620271,315724,225198,426849,2004873,50650,150971,126693,174401,77919,103230,852677,39303,66661,812413,159254,529766,338623,186542,316278,83513,234086,1049217,232078,12397193,136588,913722,209460,272691,609073,2388626,246238,266778,169690,412002,133567,268490,409981,492219,863880,84168,381968,193877,278855,418875,543159,339437,459007,403994,2114589,181178,415253,181490,940305,237615,549250,528427,1574872,270473,769275,485228,236632,214512,374422,144638,113392,79175,546890,74851,125938,80076,62317,63160,416578,124273,191594,37162,113981,84466,107643,60619,782807,87422,1705543,48081,103171,80432,52143,26286,63728,177281,246217,35656,3519472,203666,86687,175681,65642,124374,275591,67135,129727,305119,101098,147573,63680,185925,195333,28184,40766,141564,38125,29928,55287,30411,53960,38326,26144,70203,47883,81076,23831,73775,85851,56733,203289,35453,611084,56827,44541,43738,56720,273632,23597,60093,17634,41890,50589,138448,164984,377203,79449,52144,71822,45075,29240,35801,226076,83526,77162,546213,32823,198926,21184,24075,92884,44189,995767,273823,35456,13958,250874,298003,9937,42251,44727,56667,17817,52199,58286,1323833,61654,229445,63470,205364,15511,25148,11783,85638,82376,14228,17964,17209,158400,91708,13979,22905,20640,15750,20921,30602,38193,64125,157536,118900,37898,43858,10010,19613,38808,60319,183709,23225,160361,98070,20283,70254,112845,54102,29721,144147,54122,79169,127282,90156,40799,57363,125744,109512,98825,297155,42244,87274,49531,134732,23420,39298,135805,152610,90450,159254,159129,160811,60427,71498,85251,46376,121299,322681,41886,95657,117165,68654,70819,100783,207476,193362,79129,148611,185328,5329840,129393,56275,170108,399437,373574,275352,254714,532701,104627,215469,182079,204647,762293,99324,64918,60573,58366,91279,83787,498580,229138,67687,123624,78371,56339,212705,102546,417653,145821,112685,60364,321252,263445,209852,244725,364877,414396,175933,272152,234596,841176,328690,341307,320877,552435,1356776,526059,346243,656887,382253,381028,323640,756073,381727,333750,323781,847538,461292,470652,479954,367771,468247,992812,704246,853558,1363799,2206719,142239,130716,188266,233476,170125,192974,355588,711398,131615,237725,206984,272612,852919,151314,308971,209024,71316,127203,263473,155838,235382,75716,116087,2177211,59714,133218,82070,32159,711182,135008,141148,304244,84419,61801,221230,2039687,49822,183318,182259,612554,1225201,130519,2246044,93 ...

# %%
videos_df.groupby(videos_df['channelTitle'])['viewCount'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %%
videos_df.groupby(videos_df['channelTitle'])['likeCount'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %%
videos_df.groupby(videos_df['channelTitle'])['commentCount'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %%
videos_df.groupby(videos_df['channelTitle'])['viewCount'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %%
videos_df.groupby(videos_df['channelTitle'])['likeCount'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %%
videos_df.groupby(videos_df['channelTitle'])['commentCount'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='channelTitle'>

# %% [markdown]
# #**Multivariate Analysis**
#
# 1.  Pair Plot
# 2.  Heat Map
# 3.  Scatter plot with Hue, color and size
